# %%
import pandas as pd

# %%
df = pd.read_csv('vgsales.csv')

# %%
df.shape
# Out:
# (16598, 11)

# %%
df.head(6)
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
# 5     6                    Tetris       GB  1989.0        Puzzle  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37
# 5     23.20      2.26      4.22         0.58         30.26

# %%
df.head(10)
# Out:
#    Rank                       Name Platform    Year         Genre Publisher  \
# 0     1                 Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2          Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3             Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4          Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5   Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
# 5     6                     Tetris       GB  1989.0        Puzzle  Nintendo
# 6     7      New Super Mario Bros.       DS  2006.0      Platform  Nintendo
# 7     8                   Wii Play      Wii  2006.0          Misc  Nintendo
# 8     9  New Super Mario Bros. Wii      Wii  2009.0      Platform  Nintendo
# 9    10                  Duck Hunt      NES  1984.0       Shooter  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# ...

# %%
df.tail(10)
# Out:
#         Rank                                               Name Platform  \
# 16588  16591                                   Mega Brain Boost       DS
# 16589  16592  Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shiru...      PSV
# 16590  16593  Eiyuu Densetsu: Sora no Kiseki Material Collec...      PSP
# 16591  16594                                Myst IV: Revelation       PC
# 16592  16595                                           Plushees       DS
# 16593  16596                 Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                      Men in Black II: Alien Escape       GC
# 16595  16598   SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                         Know How 2       DS
# 16597  16600                                   Spirits & Spells      GBA
#
#          Year         Genre              Publisher  NA_Sales  EU_Sales  \
# 16588  2008.0        Puzzle  Majesco Entertainment      0.01      0.00
# ...

# %%
df.shape
# Out:
# (16598, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
df.describe()
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16598.000000  16327.000000  16598.000000  16598.000000  16598.000000
# mean    8300.605254   2006.406443      0.264667      0.146652      0.077782
# std     4791.853933      5.828981      0.816683      0.505351      0.309291
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4151.250000   2003.000000      0.000000      0.000000      0.000000
# 50%     8300.500000   2007.000000      0.080000      0.020000      0.000000
# 75%    12449.750000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16598.000000  16598.000000
# mean       0.048063      0.537441
# std        0.188588      1.555028
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.470000
# ...

# %%
df.value_counts
# Out:
# <bound method DataFrame.value_counts of         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
# ...

# %%
df.isnull()
# Out:
#         Rank   Name  Platform   Year  Genre  Publisher  NA_Sales  EU_Sales  \
# 0      False  False     False  False  False      False     False     False
# 1      False  False     False  False  False      False     False     False
# 2      False  False     False  False  False      False     False     False
# 3      False  False     False  False  False      False     False     False
# 4      False  False     False  False  False      False     False     False
# ...      ...    ...       ...    ...    ...        ...       ...       ...
# 16593  False  False     False  False  False      False     False     False
# 16594  False  False     False  False  False      False     False     False
# 16595  False  False     False  False  False      False     False     False
# 16596  False  False     False  False  False      False     False     False
# 16597  False  False     False  False  False      False     False     False
#
#        JP_Sales  Other_Sales  Global_Sales
# ...

# %%
df.isnull().sum()
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.columns
# Out:
# Index(['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object')

# %%
df.head(10)
# Out:
#    Rank                       Name Platform    Year         Genre Publisher  \
# 0     1                 Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2          Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3             Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4          Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5   Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
# 5     6                     Tetris       GB  1989.0        Puzzle  Nintendo
# 6     7      New Super Mario Bros.       DS  2006.0      Platform  Nintendo
# 7     8                   Wii Play      Wii  2006.0          Misc  Nintendo
# 8     9  New Super Mario Bros. Wii      Wii  2009.0      Platform  Nintendo
# 9    10                  Duck Hunt      NES  1984.0       Shooter  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# ...

# %%
df.loc[(df['Name'] == 'Cars') & (df['Year'] ==  2006.0)]
# Out:
#       Rank  Name Platform    Year   Genre Publisher  NA_Sales  EU_Sales  \
# 1641  1643  Cars      PSP  2006.0  Racing       THQ      0.72      0.29
# 1651  1653  Cars      PS2  2006.0  Racing       THQ      1.01      0.04
# 1805  1807  Cars      GBA  2006.0  Racing       THQ      0.81      0.30
# 2104  2106  Cars       DS  2006.0  Racing       THQ      0.85      0.05
# 2201  2203  Cars      Wii  2006.0  Racing       THQ      0.83      0.04
# 2239  2241  Cars       GC  2006.0  Racing       THQ      0.72      0.19
# 6649  6651  Cars     X360  2006.0  Racing       THQ      0.22      0.02
# 7582  7584  Cars       XB  2006.0  Racing       THQ      0.15      0.04
#
#       JP_Sales  Other_Sales  Global_Sales
# 1641       0.0         0.21          1.22
# 1651       0.0         0.16          1.21
# 1805       0.0         0.02          1.13
# 2104       0.0         0.08          0.98
# 2201       0.0         0.07          0.94
# 2239       0.0         0.03          0.93
# ...

# %%
df['Name'].value_counts()
# Out:
# Need for Speed: Most Wanted    12
# FIFA 14                         9
# Ratatouille                     9
# LEGO Marvel Super Heroes        9
# Cars                            8
#                                ..
# PGA Tour 96                     1
# Game & Wario                    1
# Angry Birds                     1
# Shadow Hearts: Covenant         1
# Know How 2                      1
# Name: Name, Length: 11325, dtype: int64

# %%
df.iloc[[0,5],0:3]
# Out:
#    Rank        Name Platform
# 0     1  Wii Sports      Wii
# 5     6      Tetris       GB

# %%
df.loc[[0,5],['Name','Genre','Platform','Year']]
# Out:
#          Name   Genre Platform    Year
# 0  Wii Sports  Sports      Wii  2006.0
# 5      Tetris  Puzzle       GB  1989.0

# %%
df.loc[~(df['Genre'] == 'Misc') | ~(df['Genre'] == 'Shooter')]
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
df.dtypes
# Out:
# Rank              int64
# Name             object
# Platform         object
# Year            float64
# Genre            object
# Publisher        object
# NA_Sales        float64
# EU_Sales        float64
# JP_Sales        float64
# Other_Sales     float64
# Global_Sales    float64
# dtype: object

# %%
df.loc[(df['Global_Sales'] >= 0.01) & (df['Other_Sales'] >= 1)]
# Out:
#       Rank                                       Name Platform    Year  \
# 0        1                                 Wii Sports      Wii  2006.0
# 2        3                             Mario Kart Wii      Wii  2008.0
# 3        4                          Wii Sports Resort      Wii  2009.0
# 4        5                   Pokemon Red/Pokemon Blue       GB  1996.0
# 6        7                      New Super Mario Bros.       DS  2006.0
# ...    ...                                        ...      ...     ...
# 1180  1182                  Pro Evolution Soccer 2010      PS2  2009.0
# 1249  1251                          The Simpsons Game      PS2  2007.0
# 1426  1428                              SingStar Abba      PS2  2008.0
# 1486  1488  World of Warcraft: Wrath of the Lich King       PC  2008.0
# 1518  1520                              SingStar '80s      PS2  2005.0
#
#              Genre                     Publisher  NA_Sales  EU_Sales  \
# ...

# %%
df.columns
# Out:
# Index(['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Rank              int64
# Name             object
# Platform         object
# Year            float64
# Genre            object
# Publisher        object
# NA_Sales        float64
# EU_Sales        float64
# JP_Sales        float64
# Other_Sales     float64
# Global_Sales    float64
# dtype: object

# %%
df.loc[df['Year'] == 2012.0]
# Out:
#         Rank                             Name Platform    Year       Genre  \
# 34        35       Call of Duty: Black Ops II      PS3  2012.0     Shooter
# 35        36       Call of Duty: Black Ops II     X360  2012.0     Shooter
# 64        65          New Super Mario Bros. 2      3DS  2012.0    Platform
# 65        66                           Halo 4     X360  2012.0     Shooter
# 73        74        Animal Crossing: New Leaf      3DS  2012.0  Simulation
# ...      ...                              ...      ...     ...         ...
# 16521  16524         Akatsuki no Goei Trinity      PS3  2012.0   Adventure
# 16534  16537                   Time Travelers      PSP  2012.0   Adventure
# 16537  16540  Transformers: Fall of Cybertron       PC  2012.0      Action
# 16546  16549     Hyakki Yagyou Kaidan Romance      PSP  2012.0      Action
# 16566  16569                   End of Nations       PC  2012.0    Strategy
#
# ...

# %%
df['Year'].value_counts(ascending=False)
# Out:
# 2009.0    1431
# 2008.0    1428
# 2010.0    1257
# 2007.0    1201
# 2011.0    1136
# 2006.0    1008
# 2005.0     936
# 2002.0     829
# 2003.0     775
# 2004.0     744
# 2012.0     655
# 2015.0     614
# 2014.0     580
# 2013.0     546
# 2001.0     482
# 1998.0     379
# 2000.0     349
# 2016.0     342
# 1999.0     338
# 1997.0     289
# 1996.0     263
# 1995.0     219
# 1994.0     121
# 1993.0      60
# 1981.0      46
# 1992.0      43
# 1991.0      41
# 1982.0      36
# 1986.0      21
# 1989.0      17
# 1983.0      17
# 1990.0      16
# 1987.0      16
# 1988.0      15
# 1985.0      14
# 1984.0      14
# 1980.0       9
# 2017.0       3
# 2020.0       1
# Name: Year, dtype: int64

# %%
df['Global_Sales'].value_counts(ascending = False)
# Out:
# 0.02    1045
# 0.03     795
# 0.04     634
# 0.05     624
# 0.01     600
#         ...
# 4.98       1
# 5.01       1
# 5.05       1
# 5.07       1
# 3.16       1
# Name: Global_Sales, Length: 621, dtype: int64

# %%
df.columns
# Out:
# Index(['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object')

# %%
df['Publisher'].value_counts().head(10)
# Out:
# Electronic Arts                 1339
# Activision                       966
# Namco Bandai Games               928
# Ubisoft                          918
# Konami Digital Entertainment     823
# THQ                              712
# Nintendo                         696
# Sony Computer Entertainment      682
# Sega                             632
# Take-Two Interactive             412
# Name: Publisher, dtype: int64

# %%
df.loc[df['Publisher'] == 'Microsoft Game Studios']
# Out:
#         Rank                            Name Platform    Year     Genre  \
# 15        16              Kinect Adventures!     X360  2010.0      Misc
# 43        44                          Halo 3     X360  2007.0   Shooter
# 62        63                     Halo: Reach     X360  2010.0   Shooter
# 65        66                          Halo 4     X360  2012.0   Shooter
# 72        73                       Minecraft     X360  2013.0      Misc
# ...      ...                             ...      ...     ...       ...
# 15781  15784                    Gears of War       PC  2007.0   Shooter
# 15826  15829             Exhibition Volume 6       XB  2004.0      Misc
# 16040  16043            Impossible Creatures       PC  2002.0  Strategy
# 16053  16056                   Banjo-Kazooie     X360  2008.0  Platform
# 16325  16328  RalliSport Challenge(JP sales)       XB  2002.0    Racing
#
#                     Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# ...

# %%
df.loc[df['Publisher'] == 'Sega']
# Out:
#         Rank                                       Name Platform    Year  \
# 85        86         Mario & Sonic at the Olympic Games      Wii  2007.0
# 143      144                       Sonic the Hedgehog 2      GEN  1992.0
# 189      190         Mario & Sonic at the Olympic Games       DS  2008.0
# 233      234  Mario & Sonic at the Olympic Winter Games      Wii  2009.0
# 254      255                         Sonic the Hedgehog      GEN  1991.0
# ...      ...                                        ...      ...     ...
# 16306  16309                   Full Auto 2: Battlelines      PSP  2007.0
# 16351  16354               World Snooker Challenge 2005      PSP  2005.0
# 16390  16393            World Snooker Championship 2007     X360  2007.0
# 16408  16411                            Sega Rally Revo       PC  2007.0
# 16525  16528                               Blazer Drive       DS  2008.0
#
#               Genre Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# ...

# %%
df.head(10)
# Out:
#    Rank                       Name Platform    Year         Genre Publisher  \
# 0     1                 Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2          Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3             Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4          Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5   Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
# 5     6                     Tetris       GB  1989.0        Puzzle  Nintendo
# 6     7      New Super Mario Bros.       DS  2006.0      Platform  Nintendo
# 7     8                   Wii Play      Wii  2006.0          Misc  Nintendo
# 8     9  New Super Mario Bros. Wii      Wii  2009.0      Platform  Nintendo
# 9    10                  Duck Hunt      NES  1984.0       Shooter  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# ...

# %%
df.loc[df["Name"] == 'Wii Sports']
# Out:
#    Rank        Name Platform    Year   Genre Publisher  NA_Sales  EU_Sales  \
# 0     1  Wii Sports      Wii  2006.0  Sports  Nintendo     41.49     29.02
#
#    JP_Sales  Other_Sales  Global_Sales
# 0      3.77         8.46         82.74
