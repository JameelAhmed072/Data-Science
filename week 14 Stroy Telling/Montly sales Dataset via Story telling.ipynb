# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('month_sales.csv')

# %%
df
# Out:
#     Months     sales
# 0        1  14236.90
# 1        2   4519.89
# 2        3  55691.01
# 3        4  28295.35
# 4        5  23648.29
# 5        6  34595.13
# 6        7  33946.39
# 7        8  27909.47
# 8        9  81777.35
# 9       10  31453.39
# 10      11  78628.72
# 11      12  69545.62

# %%
df.shape
# Out:
# (12, 2)

# %%
df.columns
# Out:
# Index(['Months', 'sales'], dtype='object')

# %%
df.dtypes
# Out:
# Months      int64
# sales     float64
# dtype: object

# %%
fig, (ax1,ax2,ax3) = plt.subplots(3,1,figsize = (6,8))

# %%
df
# Out:
#     Months     sales
# 0        1  14236.90
# 1        2   4519.89
# 2        3  55691.01
# 3        4  28295.35
# 4        5  23648.29
# 5        6  34595.13
# 6        7  33946.39
# 7        8  27909.47
# 8        9  81777.35
# 9       10  31453.39
# 10      11  78628.72
# 11      12  69545.62

# %%
fig, (ax1,ax2,ax3) = plt.subplots(3,1,figsize = (6,8))
axes = [ax1,ax2,ax3]
for ax in axes:
    ax.plot(df['Months'],df['sales'] ,color = "#f0240a" , alpha = 0.4)
    
plt.show()

# %% [markdown]
# # Removing Labels

# %%
fig, (ax1,ax2,ax3) = plt.subplots(3,1,figsize = (6,8))
axes = [ax1,ax2,ax3]
for ax in axes:
    ax.plot(df['Months'],df['sales'],color = "#f0240a" , alpha = 0.4)
    
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    

    
plt.show()

# %% [markdown]
# # Removing Params/Sticks

# %%
fig, (ax1,ax2,ax3) = plt.subplots(3,1,figsize = (6,8))
axes = [ax1,ax2,ax3]
for ax in axes:
    ax.plot(df['Months'],df['sales'],color = "#f0240a" , alpha = 0.4)
    
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    
    ax.tick_params(left = 0,bottom = 0)

    
plt.show()

# %% [markdown]
# # Removing Borders

# %%
fig, (ax1,ax2,ax3) = plt.subplots(3,1,figsize = (6,8))
axes = [ax1,ax2,ax3]
for ax in axes:
    ax.plot(df['Months'],df['sales'],color = "#f0240a" , alpha = 0.4)
    
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    
    ax.tick_params(left = 0,bottom = 0)

    
    borders = ['left','right','bottom','top']
    for i in borders:
        ax.spines[i].set_visible(False)
    
    
plt.show()

# %%
fig, (ax1,ax2,ax3) = plt.subplots(3,1,figsize = (6,8))
axes = [ax1,ax2,ax3]
for ax in axes:
    ax.plot(df['Months'],df['sales'],color = "#f0240a" , alpha = 0.4)
    
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    
    ax.tick_params(left = 0,bottom = 0)

    
    borders = ['left','right','bottom','top']
    for i in borders:
        ax.spines[i].set_visible(False)
    
    
ax1.plot(df['Months'][:4],df['sales'][:4],color = '#db0000',linewidth = 2.7)
ax2.plot(df['Months'][3:8],df['sales'][3:8],color = '#db6e00',linewidth = 2.7)
ax3.plot(df['Months'][7:12],df['sales'][7:12],color = '#1200db',linewidth = 2.7)
    
    
plt.show()

# %% [markdown]
# # Adding labels

# %%
fig, (ax1,ax2,ax3) = plt.subplots(3,1,figsize = (6,8))
axes = [ax1,ax2,ax3]
for ax in axes:
    ax.plot(df['Months'],df['sales'],color = "#f0240a" , alpha = 0.4)
    
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    
    ax.tick_params(left = 0,bottom = 0)

    
    borders = ['left','right','bottom','top']
    for i in borders:
        ax.spines[i].set_visible(False)
    
    
ax1.plot(df['Months'][:4],df['sales'][:4],color = '#db0000',linewidth = 2.7)
ax2.plot(df['Months'][3:8],df['sales'][3:8],color = '#db6e00',linewidth = 2.7)
ax3.plot(df['Months'][7:12],df['sales'][7:12],color = '#1200db',linewidth = 2.7)
    
    
ax1.text(0.1,100,'14236.9')
ax1.text(3.1,12100,'28295.35')    


ax2.text(3.1,12100,'28295.35')    
ax2.text(7.1,13100,'27909.47')    

    
ax3.text(7.1,13100,'27909.47')    
ax3.text(11.1,53100,'27909.47')    

    
plt.show()

# %%
fig, (ax1,ax2,ax3) = plt.subplots(3,1,figsize = (6,8))
axes = [ax1,ax2,ax3]
for ax in axes:
    ax.plot(df['Months'],df['sales'],color = "#f0240a" , alpha = 0.4)
    
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    
    ax.tick_params(left = 0,bottom = 0)

    
    borders = ['left','right','bottom','top']
    for i in borders:
        ax.spines[i].set_visible(False)
    
    
ax1.plot(df['Months'][:4],df['sales'][:4],color = '#db0000',linewidth = 2.7)
ax2.plot(df['Months'][3:8],df['sales'][3:8],color = '#db6e00',linewidth = 2.7)
ax3.plot(df['Months'][7:12],df['sales'][7:12],color = '#1200db',linewidth = 2.7)
    
    
ax1.text(0.1,100,'14236.9')
ax1.text(3.1,12100,'28295.35')    


ax2.text(3.1,12100,'28295.35')    
ax2.text(7.1,13100,'27909.47')    

    
ax3.text(7.1,13100,'27909.47')    
ax3.text(11.1,53100,'27909.47')    


ax1.text(0.7,29900,'Jan-Apr',color = '#0e038a',weight = 'bold')

ax2.text(4.7,39900,'May-Aug',color = '#f2058f',weight = 'bold')

ax3.text(10.2,29900,'Sep-Dec',color = '#0e038a',weight = 'bold')


plt.show()

# %% [markdown]
# # Adding Titles or Headers

# %%
fig, (ax1,ax2,ax3) = plt.subplots(3,1,figsize = (6,8))
axes = [ax1,ax2,ax3]
for ax in axes:
    ax.plot(df['Months'],df['sales'],color = "#f0240a" , alpha = 0.4)
    
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    
    ax.tick_params(left = 0,bottom = 0)

    
    borders = ['left','right','bottom','top']
    for i in borders:
        ax.spines[i].set_visible(False)
    
    
ax1.plot(df['Months'][:4],df['sales'][:4],color = '#db0000',linewidth = 2.7)
ax2.plot(df['Months'][3:8],df['sales'][3:8],color = '#db6e00',linewidth = 2.7)
ax3.plot(df['Months'][7:12],df['sales'][7:12],color = '#1200db',linewidth = 2.7)
    
    
ax1.text(0.1,100,'14236.9')
ax1.text(3.1,12100,'28295.35')    


ax2.text(3.1,12100,'28295.35')    
ax2.text(7.1,13100,'27909.47')    

    
ax3.text(7.1,13100,'27909.47')    
ax3.text(11.1,53100,'27909.47')    


ax1.text(0.7,29900,'Jan-Apr',color = '#0e038a',weight = 'bold')

ax2.text(4.7,39900,'May-Aug',color = '#f2058f',weight = 'bold')

ax3.text(10.2,29900,'Sep-Dec',color = '#0e038a',weight = 'bold')


ax1.text(1,99900,'The Monthly Sales',weight = 'bold',color='#f20505')


plt.show()

# %% [markdown]
# # Adding cumulative sales

# %%
df['Cumulative Sales']= df['sales'].cumsum()

# %%
df
# Out:
#     Months     sales  Cumulative Sales
# 0        1  14236.90          14236.90
# 1        2   4519.89          18756.79
# 2        3  55691.01          74447.80
# 3        4  28295.35         102743.15
# 4        5  23648.29         126391.44
# 5        6  34595.13         160986.57
# 6        7  33946.39         194932.96
# 7        8  27909.47         222842.43
# 8        9  81777.35         304619.78
# 9       10  31453.39         336073.17
# 10      11  78628.72         414701.89
# 11      12  69545.62         484247.51

# %%
sales =df.iloc[[3,7,11],:]['Cumulative Sales']

# %%
sales
# Out:
# 3     102743.15
# 7     222842.43
# 11    484247.51
# Name: Cumulative Sales, dtype: float64

# %%
sales = list(sales)

# %%
sales
# Out:
# [102743.15, 222842.43000000002, 484247.51]

# %%
fig, (ax1,ax2,ax3) = plt.subplots(3,1,figsize = (6,8))
axes = [ax1,ax2,ax3]
for ax in axes:
    ax.plot(df['Months'],df['sales'],color = "#f0240a" , alpha = 0.4)
    
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    
    ax.tick_params(left = 0,bottom = 0)

    
    borders = ['left','right','bottom','top']
    for i in borders:
        ax.spines[i].set_visible(False)
    
    
ax1.plot(df['Months'][:4],df['sales'][:4],color = '#db0000',linewidth = 2.7)
ax2.plot(df['Months'][3:8],df['sales'][3:8],color = '#db6e00',linewidth = 2.7)
ax3.plot(df['Months'][7:12],df['sales'][7:12],color = '#1200db',linewidth = 2.7)
    
    
ax1.text(0.1,100,'14236.9')
ax1.text(3.1,12100,'28295.35')    


ax2.text(3.1,12100,'28295.35')    
ax2.text(7.1,13100,'27909.47')    

    
ax3.text(7.1,13100,'27909.47')    
ax3.text(11.1,53100,'27909.47')    


ax1.text(1.7,29900,'Jan-Apr',color = '#0e038a',weight = 'bold',rotation = 65)

ax2.text(5.5,39900,'May-Aug',color = '#f2058f',weight = 'bold',rotation = 10)

ax3.text(10.2,22900,'Sep-Dec',color = '#0e038a',weight = 'bold',rotation = 65)


ax1.text(1,119900,'The Monthly Sales',weight = 'bold',color='#f20505')


n=0
for i in axes:
    i.text(3,89900,'Cumulative Sales '+str(sales[n]),color = '#5805f2',weight = 'bold')
    n += 1


plt.show()
