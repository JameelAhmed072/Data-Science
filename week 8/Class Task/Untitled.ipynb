# %%
from csv import reader
import datetime as dt

# %%
dataset = list(reader(open('catalog.csv',encoding = 'utf-8')))

# %%
dataset = dataset[1:]

# %%
for i in dataset:
    print(i)
# Out:
# ['34', '03/02/2007', 'march', 'Friday', '2007', 'United States', 'Landslide', 'Rain']
# ['42', '3/22/07', '', '', '', 'United States', 'Landslide', 'Rain']
# ['56', '04/06/2007', '', '', '', 'United States', 'Landslide', 'Rain']
# ['59', '4/14/07', '', '', '', 'Canada', 'Riverbank collapse', 'Rain']
# ['61', '4/15/07', '', '', '', 'United States', 'Landslide', 'Downpour']
# ['64', '4/20/07', '', '', '', 'United States', 'Landslide', 'Rain']
# ['67', '4/24/07', '', '', '', 'United States', 'Landslide', 'Rain']
# ['77', '5/21/07', '', '', '', 'Colombia', 'Mudslide', 'Rain']
# ['105', '6/27/07', '', '', '', 'Ecuador', 'Landslide', 'Downpour']
# ['106', '6/27/07', '', '', '', 'Ecuador', 'Landslide', 'Downpour']
# ['107', '6/27/07', '', '', '', 'Ecuador', 'Landslide', 'Downpour']
# ['109', '07/01/2007', '', '', '', 'United States', 'Landslide', 'Rain']
# ['115', '07/04/2007', '', '', '', 'Mexico', 'Landslide', 'Rain']
# ['119', '07/08/2007', '', '', '', 'Canada', 'Landslide', 'Unknown']
# ...

# %%
for i in dataset:
    print(i[1])
# Out:
# 03/02/2007
# 3/22/07
# 04/06/2007
# 4/14/07
# 4/15/07
# 4/20/07
# 4/24/07
# 5/21/07
# 6/27/07
# 6/27/07
# 6/27/07
# 07/01/2007
# 07/04/2007
# 07/08/2007
# 7/13/07
# 7/24/07
# 08/09/2007
# 08/11/2007
# 8/14/07
# 8/17/07
# 8/18/07
# 8/18/07
# 8/18/07
# 8/19/07
# 8/19/07
# 8/20/07
# 8/21/07
# 8/21/07
# 8/23/07
# 09/01/2007
# 09/02/2007
# 09/03/2007
# 09/04/2007
# 09/05/2007
# 09/05/2007
# 09/05/2007
# 09/06/2007
# 09/09/2007
# 09/09/2007
# 9/17/07
# 9/22/07
# 9/28/07
# 10/08/2007
# 10/09/2007
# 10/11/2007
# 10/11/2007
# 10/12/2007
# 10/12/2007
# 10/13/07
# 10/17/07
# 10/24/07
# 10/29/07
# 10/29/07
# 10/31/07
# 10/31/07
# 10/31/07
# 10/31/07
# 11/01/2007
# 11/04/2007
# 11/12/2007
# 11/17/07
# 11/30/07
# 12/08/2007
# 12/11/2007
# 12/11/2007
# 12/11/2007
# 12/11/2007
# 12/12/2007
# 12/16/07
# 12/19/07
# 01/01/2008
# 01/06/2008
# 01/07/2008
# 01/07/2008
# 1/28/08
# 02/05/2008
# 02/09/2008
# 2/28/08
# 03/04/2008
# 03/05/2008
# 03/09/2008
# 03/10/2008
# 3/14/08
# 3/16/08
# 3/24/08
# 3/28/08
# ...

# %% [markdown]
# ## Question 2

# %%
dataset[0]
# Out:
# ['34',
#  '03/02/2007',
#  'march',
#  'Friday',
#  '2007',
#  'United States',
#  'Landslide',
#  'Rain']

# %%
dataset[0].index('Landslide')
# Out:
# 6

# %%
landslide_type = {}
for i in dataset:
    landslide = i[6]
    if landslide not in landslide_type:
        landslide_type[landslide] = 1
    else:
        landslide_type[landslide] += 1

# %%
landslide_type
# Out:
# {'Landslide': 866,
#  'Riverbank collapse': 5,
#  'Mudslide': 635,
#  'Complex': 48,
#  'Debris flow': 38,
#  'Rockfall': 70,
#  'Lahar': 2,
#  'Creep': 5,
#  'Snow avalanche': 2,
#  'mudslide': 4,
#  'Other': 14,
#  'Unknown': 1,
#  'Rockslide': 1,
#  'landslide': 1,
#  '': 1}

# %% [markdown]
# ## Question 3 By using Nested Dictionary

# %%
countries_slides  = {}
slides = {}
lisst = []
for i in dataset:
    country = i[5]
    landslide = i[6]
    
    if country not in countries_slides:
        if landslide not in slides:
            slides[landslide] = 1
        else:
            slides[landslide] +=1
        countries_slides[country] = slides
#     else:
#         countries_slides[country] += slides

# %%
countries_slides
# Out:
# {'United States': {'Landslide': 17,
#   'Riverbank collapse': 1,
#   'Mudslide': 7,
#   'Complex': 2,
#   'Rockfall': 1},
#  'Canada': {'Landslide': 17,
#   'Riverbank collapse': 1,
#   'Mudslide': 7,
#   'Complex': 2,
#   'Rockfall': 1},
#  'Colombia': {'Landslide': 17,
#   'Riverbank collapse': 1,
#   'Mudslide': 7,
#   'Complex': 2,
#   'Rockfall': 1},
#  'Ecuador': {'Landslide': 17,
#   'Riverbank collapse': 1,
#   'Mudslide': 7,
#   'Complex': 2,
#   'Rockfall': 1},
#  'Mexico': {'Landslide': 17,
#   'Riverbank collapse': 1,
#   'Mudslide': 7,
#   'Complex': 2,
#   'Rockfall': 1},
#  'Dominican Republic': {'Landslide': 17,
#   'Riverbank collapse': 1,
#   'Mudslide': 7,
#   'Complex': 2,
#   'Rockfall': 1},
#  'Guatemala': {'Landslide': 17,
#   'Riverbank collapse': 1,
#   'Mudslide': 7,
#   'Complex': 2,
#   'Rockfall': 1},
#  'Jamaica': {'Landslide': 17,
#   'Riverbank collapse': 1,
#   'Mudslide': 7,
#   'Complex': 2,
#   'Rockfall': 1},
#  'Dominica': {'Landslide': 17,
# ...

# %% [markdown]
# ## Question 1

# %%
year_with_centuries = ('2007','2008','2009','2010','2011','2012','2013','2014','2015','2016')
date_format1 = '%m/%d/%Y'
date_format = '%m/%d/%y'

for i in dataset:
    date = i[1]
    if date == '':
        pass
    
    elif any(date.endswith(year_with_centuries)for i in year_with_centuries):
        date = dt.datetime.strptime(date,date_format1)
        i[1] = date
        
    elif date != any(date.endswith(year_with_centuries)for i in year_with_centuries):
        date = dt.datetime.strptime(date,date_format)
        i[1] = date
#     print(type(date))

# %%
for i in dataset:
    print(type(i[1]))
# Out:
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# ...

# %%
for i in dataset:
    print(type(i[2]))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# ...

# %%
strips = '%d %B %y %A'
year_with_centuries = ('2007','2008','2009','2010','2011','2012','2013','2014','2015','2016')
for i in dataset:
    
#     month = i[2]
#     day = i[3]
#     year = i[4]

    if i[1] != '':
        
        i[2] = dt.datetime.strftime(i[1],'%B')
        i[3] = dt.datetime.strftime(i[1],'%d')
        i[4] = dt.datetime.strftime(i[1],'%Y')
#     date = i[1]
#     if i[1] == '':
#         pass
    
#     elif any(i[1].endswith(year_with_centuries)for i in year_with_centuries):
#         i[1] = dt.datetime.strftime(i[1],strips)
# #         i[1] = date
        
#     elif i[1] != any(i[1].endswith(year_with_centuries)for i in year_with_centuries):
#         i[1] = dt.datetime.strftime(i[1],strips)
#     i[2].append(i[1].month)
#     i[3].append(i[1].day)
#     i[4].append(i[1].year)    
# #         i[1] = date

# %%
for i in dataset:
    print(i[2],'  ',i[3],'  ',i[4])
# Out:
# March    02    2007
# March    22    2007
# April    06    2007
# April    14    2007
# April    15    2007
# April    20    2007
# April    24    2007
# May    21    2007
# June    27    2007
# June    27    2007
# June    27    2007
# July    01    2007
# July    04    2007
# July    08    2007
# July    13    2007
# July    24    2007
# August    09    2007
# August    11    2007
# August    14    2007
# August    17    2007
# August    18    2007
# August    18    2007
# August    18    2007
# August    19    2007
# August    19    2007
# August    20    2007
# August    21    2007
# August    21    2007
# August    23    2007
# September    01    2007
# September    02    2007
# September    03    2007
# September    04    2007
# September    05    2007
# September    05    2007
# September    05    2007
# September    06    2007
# September    09    2007
# September    09    2007
# September    17    2007
# September    22    2007
# September    28    2007
# ...
