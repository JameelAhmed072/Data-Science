# %%
import pandas as pd

# %%
happiness_2015 = pd.read_csv("World_Happiness_2015.csv")
happiness_2016 = pd.read_csv("World_Happiness_2016.csv")
happiness_2017 = pd.read_csv("World_Happiness_2017.csv")

# %%
happiness_2015
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
happiness_2015["Year"] = 2015
happiness_2016["Year"] = 2016
happiness_2017["Year"] = 2017

# %%
happiness_2015.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %% [markdown]
# ## Concat

# %%
three_2015 = happiness_2015[["Country" , "Happiness Score" , "Year"]].head(3)

# %%
three_2016 = happiness_2016[["Country" , "Happiness Score" , "Year"]].head(3)

# %%
#three_2017 = happiness_2017[["Country" , "Happiness Score" , "Year"]].head(3)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5844\3348033367.py in <module>
# ----> 1 three_2017 = happiness_2017[["Country" , "Happiness Score" , "Year"]].head(3)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3509             if is_iterator(key):
#    3510                 key = list(key)
# -> 3511             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3512
#    3513         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in _get_indexer_strict(self, key, axis_name)
#    5794             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    5795
# -> 5796         self._raise_if_missing(keyarr, indexer, axis_name)
#    5797
#    5798         keyarr = self.take(indexer)
#
# ...

# %%
happiness_2017.columns = happiness_2017.columns.str.replace("." , " ")
# Out:
# C:\Users\techm\AppData\Local\Temp\ipykernel_5844\1283927388.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   happiness_2017.columns = happiness_2017.columns.str.replace("." , " ")

# %%
three_2017 = happiness_2017[["Country" , "Happiness Score" , "Year"]].head(3)

# %% [markdown]
# # pd.concat([df1 , df2] , axis)

# %%
three_2015
# Out:
#        Country  Happiness Score  Year
# 0  Switzerland            7.587  2015
# 1      Iceland            7.561  2015
# 2      Denmark            7.527  2015

# %%
three_2016
# Out:
#        Country  Happiness Score  Year
# 0      Denmark            7.526  2016
# 1  Switzerland            7.509  2016
# 2      Iceland            7.501  2016

# %%
pd.concat([three_2015 , three_2016], axis = 0 , ignore_index = True)
# Out:
#        Country  Happiness Score  Year
# 0  Switzerland            7.587  2015
# 1      Iceland            7.561  2015
# 2      Denmark            7.527  2015
# 3      Denmark            7.526  2016
# 4  Switzerland            7.509  2016
# 5      Iceland            7.501  2016

# %%
pd.concat([three_2015 , three_2016], axis = 1)
# Out:
#        Country  Happiness Score  Year      Country  Happiness Score  Year
# 0  Switzerland            7.587  2015      Denmark            7.526  2016
# 1      Iceland            7.561  2015  Switzerland            7.509  2016
# 2      Denmark            7.527  2015      Iceland            7.501  2016

# %%
pd.concat([three_2015 , three_2016 , three_2017])
# Out:
#        Country  Happiness Score  Year
# 0  Switzerland            7.587  2015
# 1      Iceland            7.561  2015
# 2      Denmark            7.527  2015
# 0      Denmark            7.526  2016
# 1  Switzerland            7.509  2016
# 2      Iceland            7.501  2016
# 0       Norway            7.537  2017
# 1      Denmark            7.522  2017
# 2      Iceland            7.504  2017

# %%
three_2015 = happiness_2015[["Country" , "Happiness Score" , "Year" , "Standard Error"]].head(3)
three_2016 = happiness_2016[["Country" , "Happiness Score" , "Year"]].head(3)

# %%
pd.concat([three_2015,three_2016])
# Out:
#        Country  Happiness Score  Year  Standard Error
# 0  Switzerland            7.587  2015         0.03411
# 1      Iceland            7.561  2015         0.04884
# 2      Denmark            7.527  2015         0.03328
# 0      Denmark            7.526  2016             NaN
# 1  Switzerland            7.509  2016             NaN
# 2      Iceland            7.501  2016             NaN

# %% [markdown]
# # Merge / Joins

# %%
three_2017
# Out:
#    Country  Happiness Score  Year
# 0   Norway            7.537  2017
# 1  Denmark            7.522  2017
# 2  Iceland            7.504  2017

# %%
three_2016
# Out:
#        Country  Happiness Score  Year
# 0      Denmark            7.526  2016
# 1  Switzerland            7.509  2016
# 2      Iceland            7.501  2016

# %%
pd.merge(left = three_2016 , right = three_2017 , on = "Country", how = "inner")
# Out:
#    Country  Happiness Score_x  Year_x  Happiness Score_y  Year_y
# 0  Denmark              7.526    2016              7.522    2017
# 1  Iceland              7.501    2016              7.504    2017

# %%
pd.merge(left = three_2016 , right = three_2017 , on = "Country", how = "left")
# Out:
#        Country  Happiness Score_x  Year_x  Happiness Score_y  Year_y
# 0      Denmark              7.526    2016              7.522  2017.0
# 1  Switzerland              7.509    2016                NaN     NaN
# 2      Iceland              7.501    2016              7.504  2017.0

# %%
pd.merge(left = three_2016 , right = three_2017 , on = "Country", how = "right")
# Out:
#    Country  Happiness Score_x  Year_x  Happiness Score_y  Year_y
# 0   Norway                NaN     NaN              7.537    2017
# 1  Denmark              7.526  2016.0              7.522    2017
# 2  Iceland              7.501  2016.0              7.504    2017

# %%
pd.merge(left = three_2016 , right = three_2017 , on = "Country", how = "right" , suffixes = (" 2016" , " 2017"))
# Out:
#    Country  Happiness Score 2016  Year 2016  Happiness Score 2017  Year 2017
# 0   Norway                   NaN        NaN                 7.537       2017
# 1  Denmark                 7.526     2016.0                 7.522       2017
# 2  Iceland                 7.501     2016.0                 7.504       2017

# %% [markdown]
# ### when column name is not same

# %%
three_2017.rename({"Country" : "country"} , axis = 1 , inplace = True)

# %%
three_2017
# Out:
#    country  Happiness Score  Year
# 0   Norway            7.537  2017
# 1  Denmark            7.522  2017
# 2  Iceland            7.504  2017

# %%
pd.merge(left = three_2016 , right = three_2017 , left_on = "Country" , right_on = "country",\
         how = "right" , suffixes = (" 2016" , " 2017"))
# Out:
#    Country  Happiness Score 2016  Year 2016  country  Happiness Score 2017  \
# 0      NaN                   NaN        NaN   Norway                 7.537
# 1  Denmark                 7.526     2016.0  Denmark                 7.522
# 2  Iceland                 7.501     2016.0  Iceland                 7.504
#
#    Year 2017
# 0       2017
# 1       2017
# 2       2017
