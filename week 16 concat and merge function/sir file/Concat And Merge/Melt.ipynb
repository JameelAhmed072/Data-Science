# %%
import pandas as pd

# %%
happiness_2015 = pd.read_csv("World_Happiness_2015.csv")

# %%
happiness_2015.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
happiness_2015[happiness_2015["Country"] == "Pakistan"]
# Out:
#      Country         Region  Happiness Rank  Happiness Score  Standard Error  \
# 80  Pakistan  Southern Asia              81            5.194         0.03726
#
#     Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 80                   0.59543  0.41411                   0.51466  0.12102
#
#     Trust (Government Corruption)  Generosity  Dystopia Residual
# 80                        0.10464     0.33671            3.10709

# %% [markdown]
# ## pd.melt(dataframe , main_colls , factors)

# %%
main_colls = happiness_2015.columns[:5]
main_colls
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error'],
#       dtype='object')

# %%
factors = happiness_2015.columns[5:]
factors
# Out:
# Index(['Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity',
#        'Dystopia Residual'],
#       dtype='object')

# %%
pd.melt(happiness_2015 , id_vars = main_colls , value_vars = factors)
# Out:
#           Country                           Region  Happiness Rank  \
# 0     Switzerland                   Western Europe               1
# 1         Iceland                   Western Europe               2
# 2         Denmark                   Western Europe               3
# 3          Norway                   Western Europe               4
# 4          Canada                    North America               5
# ...           ...                              ...             ...
# 1101       Rwanda               Sub-Saharan Africa             154
# 1102        Benin               Sub-Saharan Africa             155
# 1103        Syria  Middle East and Northern Africa             156
# 1104      Burundi               Sub-Saharan Africa             157
# 1105         Togo               Sub-Saharan Africa             158
#
#       Happiness Score  Standard Error                  variable    value
# 0               7.587         0.03411  Economy (GDP per Capita)  1.39651
# ...

# %%
melt = pd.melt(happiness_2015 , id_vars = main_colls , value_vars = factors)
melt
# Out:
#           Country                           Region  Happiness Rank  \
# 0     Switzerland                   Western Europe               1
# 1         Iceland                   Western Europe               2
# 2         Denmark                   Western Europe               3
# 3          Norway                   Western Europe               4
# 4          Canada                    North America               5
# ...           ...                              ...             ...
# 1101       Rwanda               Sub-Saharan Africa             154
# 1102        Benin               Sub-Saharan Africa             155
# 1103        Syria  Middle East and Northern Africa             156
# 1104      Burundi               Sub-Saharan Africa             157
# 1105         Togo               Sub-Saharan Africa             158
#
#       Happiness Score  Standard Error                  variable    value
# 0               7.587         0.03411  Economy (GDP per Capita)  1.39651
# ...

# %%
melt[melt["Country"] == "Pakistan"]
# Out:
#        Country         Region  Happiness Rank  Happiness Score  \
# 80    Pakistan  Southern Asia              81            5.194
# 238   Pakistan  Southern Asia              81            5.194
# 396   Pakistan  Southern Asia              81            5.194
# 554   Pakistan  Southern Asia              81            5.194
# 712   Pakistan  Southern Asia              81            5.194
# 870   Pakistan  Southern Asia              81            5.194
# 1028  Pakistan  Southern Asia              81            5.194
#
#       Standard Error                       variable    value
# 80           0.03726       Economy (GDP per Capita)  0.59543
# 238          0.03726                         Family  0.41411
# 396          0.03726       Health (Life Expectancy)  0.51466
# 554          0.03726                        Freedom  0.12102
# 712          0.03726  Trust (Government Corruption)  0.10464
# 870          0.03726                     Generosity  0.33671
# ...

# %%
happiness_2015.shape
# Out:
# (158, 12)

# %%
melt.shape
# Out:
# (1106, 7)

# %%
len(factors)
# Out:
# 7

# %%
158*7
# Out:
# 1106
