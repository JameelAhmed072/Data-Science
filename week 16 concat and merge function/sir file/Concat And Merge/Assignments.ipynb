# %%
import pandas as pd

# %% [markdown]
# # Assignment 01

# %%
happiness_2015 = pd.read_csv("World_Happiness_2015.csv")

# %%
happiness_2017 = pd.read_csv("World_Happiness_2017.csv")

# %%
happiness_2015[happiness_2015["Country"] == "Pakistan"]
# Out:
#      Country         Region  Happiness Rank  Happiness Score  Standard Error  \
# 80  Pakistan  Southern Asia              81            5.194         0.03726
#
#     Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 80                   0.59543  0.41411                   0.51466  0.12102
#
#     Trust (Government Corruption)  Generosity  Dystopia Residual
# 80                        0.10464     0.33671            3.10709

# %%
happiness_2017[happiness_2017["Country"] == "Pakistan"]
# Out:
#      Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 79  Pakistan              80            5.269      5.359984     5.178016
#
#     Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 79                  0.726884  0.672691                  0.402048  0.235215
#
#     Generosity  Trust..Government.Corruption.  Dystopia.Residual
# 79    0.315446                       0.124348           2.792489

# %%
happiness_2015.head(5)
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
happiness_2015[happiness_2015["Country"] == "Switzerland"]
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738

# %%
happiness_2017[happiness_2017["Country"] == "Switzerland"]
# Out:
#        Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 3  Switzerland               4            7.494      7.561772     7.426227
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 3                   1.56498  1.516912                  0.858131  0.620071
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual
# 3    0.290549                       0.367007           2.276716

# %%
happiness_2015.loc[0 , ["Happiness"]]

# %%
happiness_2015.iloc[0,5:] - happiness_2017.iloc[3,5:]
# Out:
# Dystopia Residual                     NaN
# Dystopia.Residual                     NaN
# Economy (GDP per Capita)              NaN
# Economy..GDP.per.Capita.              NaN
# Family                          -0.167402
# Freedom                          0.045499
# Generosity                       0.006231
# Health (Life Expectancy)              NaN
# Health..Life.Expectancy.              NaN
# Trust (Government Corruption)         NaN
# Trust..Government.Corruption.         NaN
# dtype: object

# %% [markdown]
# # Assignment 02

# %%
pd.read_csv("user_device.csv").head()
# Out:
#    use_id  user_id platform  platform_version     device  use_type_id
# 0   22782    26980      ios              10.2  iPhone7,2            2
# 1   22783    29628  android               6.0    Nexus 5            3
# 2   22784    28473  android               5.1   SM-G903F            1
# 3   22785    15200      ios              10.2  iPhone7,2            3
# 4   22786    28239  android               6.0  ONE E1003            1

# %%
pd.read_csv("user_usage.csv").head()
# Out:
#    outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb  use_id
# 0                    21.97                    4.82     1557.33   22787
# 1                  1710.08                  136.88     7267.55   22788
# 2                  1710.08                  136.88     7267.55   22789
# 3                    94.46                   35.17      519.12   22790
# 4                    71.59                   79.26     1557.33   22792
