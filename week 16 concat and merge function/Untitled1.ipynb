# %%
import pandas as pd

# %%
happiness_2015 = pd.read_csv('World_Happiness_2015.csv')

# %%
happiness_2016 = pd.read_csv('World_Happiness_2016.csv')

# %%
happiness_2017 = pd.read_csv('World_Happiness_2017.csv')

# %%
happiness_2015
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
happiness_2015['Year']  = 2015

# %%
happiness_2016['Year']  = 2016

# %%
happiness_2017['Year']  = 2017

# %%
happiness_2017.columns
# Out:
# Index(['Country', 'Happiness.Rank', 'Happiness.Score', 'Whisker.high',
#        'Whisker.low', 'Economy..GDP.per.Capita.', 'Family',
#        'Health..Life.Expectancy.', 'Freedom', 'Generosity',
#        'Trust..Government.Corruption.', 'Dystopia.Residual', 'Year'],
#       dtype='object')

# %%
happiness_2017.columns = happiness_2017.columns.str.replace(".", '')
# Out:
# C:\Users\Jameel Ahmed\AppData\Local\Temp\ipykernel_14312\24590492.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   happiness_2017.columns = happiness_2017.columns.str.replace(".", '')

# %% [markdown]
# # Concatination

# %%
happiness_2015[['Country','Happiness Score', 'Year']].head()
# Out:
#        Country  Happiness Score  Year
# 0  Switzerland            7.587  2015
# 1      Iceland            7.561  2015
# 2      Denmark            7.527  2015
# 3       Norway            7.522  2015
# 4       Canada            7.427  2015

# %%
three_2015 = happiness_2015[['Country','Happiness Score','Year']].head()

# %%
three_2015
# Out:
#        Country  Happiness Score  Year
# 0  Switzerland            7.587  2015
# 1      Iceland            7.561  2015
# 2      Denmark            7.527  2015
# 3       Norway            7.522  2015
# 4       Canada            7.427  2015

# %%
three_2016 = happiness_2016[['Country','Happiness Score','Year']].head()

# %%
three_2016
# Out:
#        Country  Happiness Score  Year
# 0      Denmark            7.526  2016
# 1  Switzerland            7.509  2016
# 2      Iceland            7.501  2016
# 3       Norway            7.498  2016
# 4      Finland            7.413  2016

# %%
happiness_2017.rename(columns = {'HappinessScore':'Happiness Score'},inplace = True)

# %%
three_2017 = happiness_2017[['Country', 'Happiness Score', 'Year']].head()

# %% [markdown]
# # Pd.concat

# %%
three_2016
# Out:
#        Country  Happiness Score  Year
# 0      Denmark            7.526  2016
# 1  Switzerland            7.509  2016
# 2      Iceland            7.501  2016
# 3       Norway            7.498  2016
# 4      Finland            7.413  2016

# %%
pd.concat([three_2015,three_2016],axis = 0,ignore_index = True )
# Out:
#        Country  Happiness Score  Year
# 0  Switzerland            7.587  2015
# 1      Iceland            7.561  2015
# 2      Denmark            7.527  2015
# 3       Norway            7.522  2015
# 4       Canada            7.427  2015
# 5      Denmark            7.526  2016
# 6  Switzerland            7.509  2016
# 7      Iceland            7.501  2016
# 8       Norway            7.498  2016
# 9      Finland            7.413  2016

# %%
three_2017
# Out:
#        Country  Happiness Score  Year
# 0       Norway            7.537  2017
# 1      Denmark            7.522  2017
# 2      Iceland            7.504  2017
# 3  Switzerland            7.494  2017
# 4      Finland            7.469  2017

# %%
pd.concat([three_2015,three_2016,three_2017],axis = 0,ignore_index = True )
# Out:
#         Country  Happiness Score  Year
# 0   Switzerland            7.587  2015
# 1       Iceland            7.561  2015
# 2       Denmark            7.527  2015
# 3        Norway            7.522  2015
# 4        Canada            7.427  2015
# 5       Denmark            7.526  2016
# 6   Switzerland            7.509  2016
# 7       Iceland            7.501  2016
# 8        Norway            7.498  2016
# 9       Finland            7.413  2016
# 10       Norway            7.537  2017
# 11      Denmark            7.522  2017
# 12      Iceland            7.504  2017
# 13  Switzerland            7.494  2017
# 14      Finland            7.469  2017

# %%
three_2015_a = happiness_2015[['Country','Happiness Score','Year', 'Standard Error']].head()

# %%
three_2016
# Out:
#        Country  Happiness Score  Year
# 0      Denmark            7.526  2016
# 1  Switzerland            7.509  2016
# 2      Iceland            7.501  2016
# 3       Norway            7.498  2016
# 4      Finland            7.413  2016

# %%
pd.concat([three_2015_a,three_2016]) # NaN Values will print when we dont have values for that dataset
# Out:
#        Country  Happiness Score  Year  Standard Error
# 0  Switzerland            7.587  2015         0.03411
# 1      Iceland            7.561  2015         0.04884
# 2      Denmark            7.527  2015         0.03328
# 3       Norway            7.522  2015         0.03880
# 4       Canada            7.427  2015         0.03553
# 0      Denmark            7.526  2016             NaN
# 1  Switzerland            7.509  2016             NaN
# 2      Iceland            7.501  2016             NaN
# 3       Norway            7.498  2016             NaN
# 4      Finland            7.413  2016             NaN

# %% [markdown]
# # Merge / Join

# %%
three_2017
# Out:
#        Country  Happiness Score  Year
# 0       Norway            7.537  2017
# 1      Denmark            7.522  2017
# 2      Iceland            7.504  2017
# 3  Switzerland            7.494  2017
# 4      Finland            7.469  2017

# %%
three_2016
# Out:
#        Country  Happiness Score  Year
# 0      Denmark            7.526  2016
# 1  Switzerland            7.509  2016
# 2      Iceland            7.501  2016
# 3       Norway            7.498  2016
# 4      Finland            7.413  2016

# %%
three_2015
# Out:
#        Country  Happiness Score  Year
# 0  Switzerland            7.587  2015
# 1      Iceland            7.561  2015
# 2      Denmark            7.527  2015
# 3       Norway            7.522  2015
# 4       Canada            7.427  2015

# %%
pd.merge(left = three_2016,right = three_2017,on = 'Country',how = 'inner')
# Out:
#        Country  Happiness Score_x  Year_x  Happiness Score_y  Year_y
# 0      Denmark              7.526    2016              7.522    2017
# 1  Switzerland              7.509    2016              7.494    2017
# 2      Iceland              7.501    2016              7.504    2017
# 3       Norway              7.498    2016              7.537    2017
# 4      Finland              7.413    2016              7.469    2017

# %%
pd.merge(left = three_2016,right = three_2017,on = 'Country', how = 'right')
# Out:
#        Country  Happiness Score_x  Year_x  Happiness Score_y  Year_y
# 0       Norway              7.498    2016              7.537    2017
# 1      Denmark              7.526    2016              7.522    2017
# 2      Iceland              7.501    2016              7.504    2017
# 3  Switzerland              7.509    2016              7.494    2017
# 4      Finland              7.413    2016              7.469    2017

# %%
pd.merge(left = three_2016,right = three_2017,on = 'Country',how = 'left')
# Out:
#        Country  Happiness Score_x  Year_x  Happiness Score_y  Year_y
# 0      Denmark              7.526    2016              7.522    2017
# 1  Switzerland              7.509    2016              7.494    2017
# 2      Iceland              7.501    2016              7.504    2017
# 3       Norway              7.498    2016              7.537    2017
# 4      Finland              7.413    2016              7.469    2017

# %%
pd.merge(left = three_2016,right = three_2017,on = 'Country')
# Out:
#        Country  Happiness Score_x  Year_x  Happiness Score_y  Year_y
# 0      Denmark              7.526    2016              7.522    2017
# 1  Switzerland              7.509    2016              7.494    2017
# 2      Iceland              7.501    2016              7.504    2017
# 3       Norway              7.498    2016              7.537    2017
# 4      Finland              7.413    2016              7.469    2017
