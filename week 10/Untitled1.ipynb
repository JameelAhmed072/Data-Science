# %%
from csv import reader
import datetime as dt

# %%
dataset = list(reader(open('EPL_Set.csv',encoding = 'utf-8')))

# %%
dataset
# Out:
# [['\ufeffDiv',
#   'Date',
#   'HomeTeam',
#   'AwayTeam',
#   'FTHG',
#   'FTAG',
#   'FTR',
#   'HTHG',
#   'HTAG',
#   'HTR',
#   'Season'],
#  ['E0',
#   '14/08/93',
#   'Arsenal',
#   'Coventry',
#   '0',
#   '3',
#   'A',
#   '',
#   '',
#   '',
#   '1993-94'],
#  ['E0',
#   '14/08/93',
#   'Aston Villa',
#   'QPR',
#   '4',
#   '1',
#   'H',
#   '',
#   '',
#   '',
#   '1993-94'],
#  ['E0',
#   '14/08/93',
#   'Chelsea',
#   'Blackburn',
#   '1',
#   '2',
#   'A',
#   '',
#   '',
#   '',
#   '1993-94'],
#  ['E0',
#   '14/08/93',
#   'Liverpool',
#   'Sheffield Weds',
#   '2',
#   '0',
#   'H',
#   '',
#   '',
#   '',
#   '1993-94'],
#  ['E0', '14/08/93', 'Man City', 'Leeds', '1', '1', 'D', '', '', '', '1993-94'],
#  ['E0',
#   '14/08/93',
#   'Newcastle',
#   'Tottenham',
#   '0',
#   '1',
#   'A',
#   '',
#   '',
#   '',
#   '1993-94'],
#  ['E0', '14/08/93', 'Oldham', 'Ipswich', '0', '3', 'A', '', '', '', '1993-94'],
#  ['E0',
#   '14/08/93',
#   'Sheffield United',
# ...

# %%
header = dataset[0]

# %%
header
# Out:
# ['\ufeffDiv',
#  'Date',
#  'HomeTeam',
#  'AwayTeam',
#  'FTHG',
#  'FTAG',
#  'FTR',
#  'HTHG',
#  'HTAG',
#  'HTR',
#  'Season']

# %%
dataset = dataset[1:]

# %%
header
# Out:
# ['\ufeffDiv',
#  'Date',
#  'HomeTeam',
#  'AwayTeam',
#  'FTHG',
#  'FTAG',
#  'FTR',
#  'HTHG',
#  'HTAG',
#  'HTR',
#  'Season']

# %%
for i in dataset:
    season = i[10]
    
    if season == '2006-07':
# Out:
# ['E0', '19/08/06', 'Arsenal', 'Aston Villa', '1', '1', 'D', '0', '0', 'D', '2006-07']
# ['E0', '19/08/06', 'Bolton', 'Tottenham', '2', '0', 'H', '2', '0', 'H', '2006-07']
# ['E0', '19/08/06', 'Everton', 'Watford', '2', '1', 'H', '1', '0', 'H', '2006-07']
# ['E0', '19/08/06', 'Newcastle', 'Wigan', '2', '1', 'H', '1', '0', 'H', '2006-07']
# ['E0', '19/08/06', 'Portsmouth', 'Blackburn', '3', '0', 'H', '1', '0', 'H', '2006-07']
# ['E0', '19/08/06', 'Reading', 'Middlesbrough', '3', '2', 'H', '2', '2', 'D', '2006-07']
# ['E0', '19/08/06', 'Sheffield United', 'Liverpool', '1', '1', 'D', '0', '0', 'D', '2006-07']
# ['E0', '19/08/06', 'West Ham', 'Charlton', '3', '1', 'H', '0', '1', 'A', '2006-07']
# ['E0', '20/08/06', 'Chelsea', 'Man City', '3', '0', 'H', '2', '0', 'H', '2006-07']
# ['E0', '20/08/06', 'Man United', 'Fulham', '5', '1', 'H', '4', '1', 'H', '2006-07']
# ['E0', '22/08/06', 'Tottenham', 'Sheffield United', '2', '0', 'H', '2', '0', 'H', '2006-07']
# ...

# %%
formated = '%d/%m/%y'
for i in dataset:
    date = i[1]
#     print(date)
    
    date = dt.datetime.strptime(date,formated)
    i[1] =  date
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [54], in <cell line: 2>()
#       3     date = i[1]
#       4 #     print(date)
# ----> 6     date = dt.datetime.strptime(date,formated)
#       7     i[1] =  date
#
# TypeError: strptime() argument 1 must be str, not datetime.datetime

# %%
for i in dataset:
    print(type(i[1]))
# Out:
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# ...

# %%
for i in dataset:
    print(type(i[1]))
# Out:
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# <class 'datetime.datetime'>
# ...

# %%
formated = '%d/%m/%y'
for i in dataset:
    season = i[10]
    date = i[1]
    if season == '2006-07':
        date = dt.datetime.strptime(date,formated)
        i[1] = date
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [61], in <cell line: 2>()
#       4 date = i[1]
#       5 if season == '2006-07':
# ----> 6     date = dt.datetime.strptime(date,formated)
#       7     i[1] = date
#
# File C:\conddda\lib\_strptime.py:568, in _strptime_datetime(cls, data_string, format)
#     565 def _strptime_datetime(cls, data_string, format="%a %b %d %H:%M:%S %Y"):
#     566     """Return a class cls instance based on the input string and the
#     567     format string."""
# --> 568     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#     569     tzname, gmtoff = tt[-2:]
#     570     args = tt[:6] + (fraction,)
#
# File C:\conddda\lib\_strptime.py:352, in _strptime(data_string, format)
#     349     raise ValueError("time data %r does not match format %r" %
#     350                      (data_string, format))
# ...

# %%
for i in dataset:
    if 
    if i[10] == '2006-07':
        print( i[1]   ,'   ',type(i[1]))
# Out:
# 2006-08-19 00:00:00     <class 'datetime.datetime'>
# 2006-08-19 00:00:00     <class 'datetime.datetime'>
# 2006-08-19 00:00:00     <class 'datetime.datetime'>
# 2006-08-19 00:00:00     <class 'datetime.datetime'>
# 2006-08-19 00:00:00     <class 'datetime.datetime'>
# 2006-08-19 00:00:00     <class 'datetime.datetime'>
# 2006-08-19 00:00:00     <class 'datetime.datetime'>
# 2006-08-19 00:00:00     <class 'datetime.datetime'>
# 2006-08-20 00:00:00     <class 'datetime.datetime'>
# 2006-08-20 00:00:00     <class 'datetime.datetime'>
# 2006-08-22 00:00:00     <class 'datetime.datetime'>
# 2006-08-22 00:00:00     <class 'datetime.datetime'>
# 2006-08-23 00:00:00     <class 'datetime.datetime'>
# 2006-08-23 00:00:00     <class 'datetime.datetime'>
# 2006-08-23 00:00:00     <class 'datetime.datetime'>
# 2006-08-23 00:00:00     <class 'datetime.datetime'>
# 2006-08-23 00:00:00     <class 'datetime.datetime'>
# 2006-08-23 00:00:00     <class 'datetime.datetime'>
# ...
