# %%
import pandas as pd

# %%
df =pd.read_csv('EPL_Set.csv')

# %%
df
# Out:
#      Div      Date     HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0     E0  14/08/93      Arsenal        Coventry     0     3   A   NaN   NaN
# 1     E0  14/08/93  Aston Villa             QPR     4     1   H   NaN   NaN
# 2     E0  14/08/93      Chelsea       Blackburn     1     2   A   NaN   NaN
# 3     E0  14/08/93    Liverpool  Sheffield Weds     2     0   H   NaN   NaN
# 4     E0  14/08/93     Man City           Leeds     1     1   D   NaN   NaN
# ...   ..       ...          ...             ...   ...   ...  ..   ...   ...
# 9659  E0  13/05/18    Newcastle         Chelsea     3     0   H   1.0   0.0
# 9660  E0  13/05/18  Southampton        Man City     0     1   A   0.0   0.0
# 9661  E0  13/05/18      Swansea           Stoke     1     2   A   1.0   2.0
# 9662  E0  13/05/18    Tottenham       Leicester     5     4   H   1.0   2.0
# 9663  E0  13/05/18     West Ham         Everton     3     1   H   1.0   0.0
#
#       HTR   Season
# 0     NaN  1993-94
# ...

# %%
df.columns
# Out:
# Index(['Div', 'Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HTHG',
#        'HTAG', 'HTR', 'Season'],
#       dtype='object')

# %%
df['FTR'].unique()
# Out:
# array(['A', 'H', 'D'], dtype=object)

# %%
df['Date']
# Out:
# 0       14/08/93
# 1       14/08/93
# 2       14/08/93
# 3       14/08/93
# 4       14/08/93
#           ...
# 9659    13/05/18
# 9660    13/05/18
# 9661    13/05/18
# 9662    13/05/18
# 9663    13/05/18
# Name: Date, Length: 9664, dtype: object

# %%
df.dtypes
# Out:
# Div          object
# Date         object
# HomeTeam     object
# AwayTeam     object
# FTHG          int64
# FTAG          int64
# FTR          object
# HTHG        float64
# HTAG        float64
# HTR          object
# Season       object
# dtype: object

# %%
season=df.loc[df['Season']== '2006-07']

# %%
season.head(20)
# Out:
#      Div      Date          HomeTeam          AwayTeam  FTHG  FTAG FTR  HTHG  \
# 5104  E0  19/08/06           Arsenal       Aston Villa     1     1   D   0.0
# 5105  E0  19/08/06            Bolton         Tottenham     2     0   H   2.0
# 5106  E0  19/08/06           Everton           Watford     2     1   H   1.0
# 5107  E0  19/08/06         Newcastle             Wigan     2     1   H   1.0
# 5108  E0  19/08/06        Portsmouth         Blackburn     3     0   H   1.0
# 5109  E0  19/08/06           Reading     Middlesbrough     3     2   H   2.0
# 5110  E0  19/08/06  Sheffield United         Liverpool     1     1   D   0.0
# 5111  E0  19/08/06          West Ham          Charlton     3     1   H   0.0
# 5112  E0  20/08/06           Chelsea          Man City     3     0   H   2.0
# 5113  E0  20/08/06        Man United            Fulham     5     1   H   4.0
# 5114  E0  22/08/06         Tottenham  Sheffield United     2     0   H   2.0
# ...

# %%
season['HomeTeam'].unique()
# Out:
# array(['Arsenal', 'Bolton', 'Everton', 'Newcastle', 'Portsmouth',
#        'Reading', 'Sheffield United', 'West Ham', 'Chelsea', 'Man United',
#        'Tottenham', 'Watford', 'Aston Villa', 'Blackburn', 'Charlton',
#        'Fulham', 'Man City', 'Middlesbrough', 'Liverpool', 'Wigan'],
#       dtype=object)

# %%
df['MP'] = ''

# %%
season.insert(11,'MP',0,True)

# %%
season.dtypes
# Out:
# Div          object
# Date         object
# HomeTeam     object
# AwayTeam     object
# FTHG          int64
# FTAG          int64
# FTR          object
# HTHG        float64
# HTAG        float64
# HTR          object
# Season       object
# MP            int64
# dtype: object

# %%
df.dtypes
# Out:
# Div          object
# Date         object
# HomeTeam     object
# AwayTeam     object
# FTHG          int64
# FTAG          int64
# FTR          object
# HTHG        float64
# HTAG        float64
# HTR          object
# Season       object
# MP           object
# dtype: object

# %%
season['W'] = 0
# Out:
# C:\Users\Jameel Ahmed\AppData\Local\Temp\ipykernel_2084\2853432236.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   season['W'] = 0

# %%
df.drop(['MP'],axis = 1,inplace = True)

# %%
df.head()
# Out:
#   Div      Date     HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  HTR  \
# 0  E0  14/08/93      Arsenal        Coventry     0     3   A   NaN   NaN  NaN
# 1  E0  14/08/93  Aston Villa             QPR     4     1   H   NaN   NaN  NaN
# 2  E0  14/08/93      Chelsea       Blackburn     1     2   A   NaN   NaN  NaN
# 3  E0  14/08/93    Liverpool  Sheffield Weds     2     0   H   NaN   NaN  NaN
# 4  E0  14/08/93     Man City           Leeds     1     1   D   NaN   NaN  NaN
#
#     Season
# 0  1993-94
# 1  1993-94
# 2  1993-94
# 3  1993-94
# 4  1993-94

# %%
season['D'] = 0
# Out:
# C:\Users\Jameel Ahmed\AppData\Local\Temp\ipykernel_2084\1737081305.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   season['D'] = 0

# %%
season['L'] = 0
# Out:
# C:\Users\Jameel Ahmed\AppData\Local\Temp\ipykernel_2084\3079167742.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   season['L'] = 0

# %%
season['GF'] = 0
# Out:
# C:\Users\Jameel Ahmed\AppData\Local\Temp\ipykernel_2084\2992826525.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   season['GF'] = 0

# %%
season['GA'] = 0
# Out:
# C:\Users\Jameel Ahmed\AppData\Local\Temp\ipykernel_2084\2542087914.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   season['GA'] = 0

# %%
season['GD'] = 0
# Out:
# C:\Users\Jameel Ahmed\AppData\Local\Temp\ipykernel_2084\3507552110.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   season['GD'] = 0

# %%
season['Pts'] = 0
# Out:
# C:\Users\Jameel Ahmed\AppData\Local\Temp\ipykernel_2084\428584589.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   season['Pts'] = 0

# %%
df['MP']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\conddda\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File C:\conddda\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\conddda\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'MP'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df['MP'] = pd.to_integer(df['MP'])

# %%
df.dtypes

# %%
season.head(20)

# %%
season.to_csv('season 2006-07.csv',index = False)

# %%
season.head()

# %%
import pandas as pf

# %%
df = pd.read_csv('season 2006-07.csv')

# %%
df

# %%
season.insert(11,'MP',0,True)

# %%
season.drop(['MP'],axis=1,inplace = True)

# %%
season.insert(11,'MP',0,True)

# %%
season.insert(13,'D',0,True)

# %%
season.insert(13,'L',0,True)

# %%
season.head()

# %%
season.to_csv('2006-07.csv',index = False)

# %%
sea = pd.read_csv('2006-07.csv')

# %%
sea
# Out:
#     Div      Date          HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0    E0  19/08/06           Arsenal  Aston Villa     1     1   D   0.0   0.0
# 1    E0  19/08/06            Bolton    Tottenham     2     0   H   2.0   0.0
# 2    E0  19/08/06           Everton      Watford     2     1   H   1.0   0.0
# 3    E0  19/08/06         Newcastle        Wigan     2     1   H   1.0   0.0
# 4    E0  19/08/06        Portsmouth    Blackburn     3     0   H   1.0   0.0
# ..   ..       ...               ...          ...   ...   ...  ..   ...   ...
# 375  E0  13/05/07     Middlesbrough       Fulham     3     1   H   2.0   1.0
# 376  E0  13/05/07        Portsmouth      Arsenal     0     0   D   0.0   0.0
# 377  E0  13/05/07  Sheffield United        Wigan     1     2   A   1.0   2.0
# 378  E0  13/05/07         Tottenham     Man City     2     1   H   2.0   1.0
# 379  E0  13/05/07           Watford    Newcastle     1     1   D   0.0   1.0
#
# ...

# %%
sea.columns
# Out:
# Index(['Div', 'Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HTHG',
#        'HTAG', 'HTR', 'Season', 'MP', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts'],
#       dtype='object')

# %%
sea
# Out:
#     Div      Date          HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0    E0  19/08/06           Arsenal  Aston Villa     1     1   D   0.0   0.0
# 1    E0  19/08/06            Bolton    Tottenham     2     0   H   2.0   0.0
# 2    E0  19/08/06           Everton      Watford     2     1   H   1.0   0.0
# 3    E0  19/08/06         Newcastle        Wigan     2     1   H   1.0   0.0
# 4    E0  19/08/06        Portsmouth    Blackburn     3     0   H   1.0   0.0
# ..   ..       ...               ...          ...   ...   ...  ..   ...   ...
# 375  E0  13/05/07     Middlesbrough       Fulham     3     1   H   2.0   1.0
# 376  E0  13/05/07        Portsmouth      Arsenal     0     0   D   0.0   0.0
# 377  E0  13/05/07  Sheffield United        Wigan     1     2   A   1.0   2.0
# 378  E0  13/05/07         Tottenham     Man City     2     1   H   2.0   1.0
# 379  E0  13/05/07           Watford    Newcastle     1     1   D   0.0   1.0
#
# ...

# %%
sea['HomeTeam'].value_counts()
# Out:
# Arsenal             19
# Bolton              19
# Liverpool           19
# Middlesbrough       19
# Man City            19
# Fulham              19
# Charlton            19
# Blackburn           19
# Aston Villa         19
# Watford             19
# Tottenham           19
# Man United          19
# Chelsea             19
# West Ham            19
# Sheffield United    19
# Reading             19
# Portsmouth          19
# Newcastle           19
# Everton             19
# Wigan               19
# Name: HomeTeam, dtype: int64

# %%
sea['AwayTeam'].value_counts()
# Out:
# Aston Villa         19
# Tottenham           19
# Arsenal             19
# Chelsea             19
# Portsmouth          19
# Bolton              19
# Man United          19
# Everton             19
# Reading             19
# West Ham            19
# Sheffield United    19
# Fulham              19
# Man City            19
# Charlton            19
# Liverpool           19
# Middlesbrough       19
# Blackburn           19
# Wigan               19
# Watford             19
# Newcastle           19
# Name: AwayTeam, dtype: int64

# %%
sea[['HomeTeam','AwayTeam']]
# Out:
#              HomeTeam     AwayTeam
# 0             Arsenal  Aston Villa
# 1              Bolton    Tottenham
# 2             Everton      Watford
# 3           Newcastle        Wigan
# 4          Portsmouth    Blackburn
# ..                ...          ...
# 375     Middlesbrough       Fulham
# 376        Portsmouth      Arsenal
# 377  Sheffield United        Wigan
# 378         Tottenham     Man City
# 379           Watford    Newcastle
#
# [380 rows x 2 columns]
