# %% [markdown]
# # Locating Elements

# %% [markdown]
# Selenium provides the following method to locate elements in a page:
#
#     find_element
#
# To find multiple elements (these methods will return a list):
#
#     find_elements

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The attributes available for the By class are used to locate elements on a page. These are the attributes available for By class:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The ‘By’ class is used to specify which attribute is used to locate elements on a page. These are the various ways the attributes are used to locate elements on a page:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# If you want to locate several elements with the same attribute replace find_element with find_elements.

# %% [markdown]
# # XPATH Syntax

# %% [markdown]
# <span class="currency--GVKjl">Rs. 1,250</span>

# %%
//span[@class='currency--GVKjl']

# %%
<div class="gridItem--Yd0sa" data-qa-locator="product-item" data-tracking="product-card" data-sku-simple="" data-item-id="396263494" data-aplus-ae="x1_6cb2a1e2" data-spm-anchor-id="a2a0e.searchlist.list.i0.779c2d2b8VifE7"><div class="box--pRqdD boxWithSku--Abyff"><div class="inner--SODwy"><div class="img--VQr82"><div class="mainPic--ehOdr"><a age="0" href="//www.daraz.pk/products/fashion-mens-watches-stainless-steel-quartz-wristwatch-calendar-clock-men-business-casual-mesh-belt-watch-i396263494-s1921464080.html?search=1"><img class="image--WOyuZ " src="https://static-01.daraz.pk/p/7a0cde43980864e13b57622a53e76a57.jpg" alt="Fashion Mens Watches Stainless Steel Quartz Wristwatch Calendar Clock Men Business Casual Mesh Belt Watch" age="0"></a></div><div class="skus--RQ5b1"><div class="staticSlider--JIqN8"><div class="item--IRNjh"><a age="0" class="sku--JjESd active--TTaLe" href="/products/fashion-mens-watches-stainless-steel-quartz-wristwatch-calendar-clock-men-business-casual-mesh-belt-watch-i396263494-s1921464080.html"><img class="image--WOyuZ " src="https://static-01.daraz.pk/p/7a0cde43980864e13b57622a53e76a57.jpg" age="0"></a></div></div></div></div><div class="info--ifj7U"><div class="tag--huSJx"><i class="ic-dynamic-badge ic-dynamic-badge-lazMall ic-dynamic-group-1" style="background-image: url(&quot;//img.alicdn.com/imgextra/i2/O1CN0192vi4w22yc3IH1uKk_!!6000000007189-2-tps-192-96.png&quot;); width: 33.2308px; height: 16px;"></i></div><div class="title--wFj93"><a age="0" href="//www.daraz.pk/products/fashion-mens-watches-stainless-steel-quartz-wristwatch-calendar-clock-men-business-casual-mesh-belt-watch-i396263494-s1921464080.html?search=1" title="Fashion Mens Watches Stainless Steel Quartz Wristwatch Calendar Clock Men Business Casual Mesh Belt Watch">Fashion Mens Watches Stainless Steel Quartz Wristwatch Calendar Clock Men Business Casual Mesh Belt Watch</a></div><div class="price--NVB62"><span class="currency--GVKjl">Rs. 1,250</span></div><div class="priceExtra--ocAYk"><span class="origPrice--AJxRs"><del class="currency--GVKjl">Rs. 1,923</del></span><span class="discount--HADrg">-35%</span><i class="ic-dynamic-badge ic-dynamic-badge-freeShipping ic-dynamic-group-2" style="background-image: url(&quot;//laz-img-cdn.alicdn.com/tfs/TB1QTkMXG67gK0jSZFHXXa9jVXa-45-28.png&quot;); width: 25.7143px; height: 16px;"></i></div><div class="rateAndLoc--XWchq"><span class="location--eh0Ro freeShipping--l5k4N" title="Free Shipping">Free Shipping</span></div></div></div></div></div>

# %%
//div[@class='gridItem--Yd0sa']

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## XPATH Example :
#
# ### Daraz.pk
#
# #### For whole product
#     //div[@class="gridItem--Yd0sa"][1]
#
# #### For prices only
#     //span[@class="currency--GVKjl"]
#
# #### Add bracket for for indexing
#     (//span[@class="currency--GVKjl"])[3]
