# %%
open_file = open('matches.csv', encoding = "utf-8")

# %%
import csv

# %%
readfile = csv.reader(open_file)

# %%
readfile

# %%
dataset = list(readfile)

# %%
dataset
# Out:
# [['id',
#   'season',
#   'city',
#   'date',
#   'team1',
#   'team2',
#   'toss_winner',
#   'toss_decision',
#   'result',
#   'dl_applied',
#   'winner',
#   'win_by_runs',
#   'win_by_wickets',
#   'player_of_match',
#   'venue',
#   'umpire1',
#   'umpire2',
#   'umpire3'],
#  ['1',
#   '2017',
#   'Hyderabad',
#   '05/04/2017',
#   'Sunrisers Hyderabad',
#   'Royal Challengers Bangalore',
#   'Royal Challengers Bangalore',
#   'field',
#   'normal',
#   '0',
#   'Sunrisers Hyderabad',
#   '35',
#   '0',
#   'Yuvraj Singh',
#   'Rajiv Gandhi International Stadium, Uppal',
#   'AY Dandekar',
#   'NJ Llong',
#   ''],
#  ['2',
#   '2017',
#   'Pune',
#   '06/04/2017',
#   'Mumbai Indians',
#   'Rising Pune Supergiant',
#   'Rising Pune Supergiant',
#   'field',
#   'normal',
#   '0',
#   'Rising Pune Supergiant',
#   '0',
#   '7',
#   'SPD Smith',
#   'Maharashtra Cricket Association Stadium',
#   'A Nand Kishore',
#   'S Ravi',
#   ''],
#  ['3',
#   '2017',
#   'Rajkot',
# ...

# %%
dataset[0]
# Out:
# ['id',
#  'season',
#  'city',
#  'date',
#  'team1',
#  'team2',
#  'toss_winner',
#  'toss_decision',
#  'result',
#  'dl_applied',
#  'winner',
#  'win_by_runs',
#  'win_by_wickets',
#  'player_of_match',
#  'venue',
#  'umpire1',
#  'umpire2',
#  'umpire3']

# %%
for i in dataset[1:41]:
    print(i)
# Out:
# ['1', '2017', 'Hyderabad', '2017-04-05', 'Sunrisers Hyderabad', 'Royal Challengers Bangalore', 'Royal Challengers Bangalore', 'field', 'normal', '0', 'Sunrisers Hyderabad', '35', '0', 'Yuvraj Singh', 'Rajiv Gandhi International Stadium, Uppal', 'AY Dandekar', 'NJ Llong', '']
# ['2', '2017', 'Pune', '2017-04-06', 'Mumbai Indians', 'Rising Pune Supergiant', 'Rising Pune Supergiant', 'field', 'normal', '0', 'Rising Pune Supergiant', '0', '7', 'SPD Smith', 'Maharashtra Cricket Association Stadium', 'A Nand Kishore', 'S Ravi', '']
# ['3', '2017', 'Rajkot', '2017-04-07', 'Gujarat Lions', 'Kolkata Knight Riders', 'Kolkata Knight Riders', 'field', 'normal', '0', 'Kolkata Knight Riders', '0', '10', 'CA Lynn', 'Saurashtra Cricket Association Stadium', 'Nitin Menon', 'CK Nandan', '']
# ...

# %%
dataset[0].index('result')
# Out:
# 8

# %%
for i in dataset[1:]:
    res = i[8]
    if res != 'normal':
        print(res)
# Out:
# tie
# tie
# tie
# no result
# tie
# tie
# tie
# tie
# no result
# no result
# tie
# no result
# tie

# %%
dataset[0].index('player_of_match')
# Out:
# 13

# %%
for i in dataset[1:]:
    mom = i[13]
    if mom == 'Rashid Khan':
        print(mom)
# Out:
# Rashid Khan
# Rashid Khan
# Rashid Khan
# Rashid Khan
# Rashid Khan
# Rashid Khan
# Rashid Khan

# %%
for i in dataset[1:]:
    mom = i[13]
    if mom == 'V Kohli':
        print(mom)
# Out:
# V Kohli
# V Kohli
# V Kohli
# V Kohli
# V Kohli
# V Kohli
# V Kohli
# V Kohli
# V Kohli
# V Kohli
# V Kohli
# V Kohli

# %%
for i in dataset[1:]:
    mom = i[13]
    if mom == 'Yuvraj Singh':
        print(mom)
# Out:
# Yuvraj Singh
# Yuvraj Singh
# Yuvraj Singh
# Yuvraj Singh
# Yuvraj Singh

# %%
for i in dataset[1:]:
    mom = i[13]
    if mom == 'MS Dhoni':
        print(mom)
# Out:
# MS Dhoni
# MS Dhoni
# MS Dhoni
# MS Dhoni
# MS Dhoni
# MS Dhoni
# MS Dhoni
# MS Dhoni
# MS Dhoni
# MS Dhoni
# MS Dhoni
# MS Dhoni
# MS Dhoni
# MS Dhoni
# MS Dhoni
# MS Dhoni
# MS Dhoni

# %%
dataset[0].index('winner')
# Out:
# 10

# %%
Sunrisers_Hyderabad_win = []

for i in dataset[1:]:
    win = i[10]
    if win == 'Sunrisers Hyderabad': 
        Sunrisers_Hyderabad_win.append(win)

# %%
Sunrisers_Hyderabad_win
# Out:
# ['Sunrisers Hyderabad',
#  'Sunrisers Hyderabad',
#  'Sunrisers Hyderabad',
#  'Sunrisers Hyderabad',
#  'Sunrisers Hyderabad',
#  'Sunrisers Hyderabad',
#  'Sunrisers Hyderabad',
#  'Sunrisers Hyderabad',
#  'Sunrisers Hyderabad',
#  'Sunrisers Hyderabad',
#  'Sunrisers Hyderabad',
#  'Sunrisers Hyderabad',
#  'Sunrisers Hyderabad',
#  'Sunrisers Hyderabad',
#  'Sunrisers Hyderabad',
#  'Sunrisers Hyderabad',
#  'Sunrisers Hyderabad',
#  'Sunrisers Hyderabad',
#  'Sunrisers Hyderabad',
#  'Sunrisers Hyderabad',
#  'Sunrisers Hyderabad',
#  'Sunrisers Hyderabad',
#  'Sunrisers Hyderabad',
#  'Sunrisers Hyderabad',
#  'Sunrisers Hyderabad',
#  'Sunrisers Hyderabad',
#  'Sunrisers Hyderabad',
#  'Sunrisers Hyderabad',
#  'Sunrisers Hyderabad',
#  'Sunrisers Hyderabad',
#  'Sunrisers Hyderabad',
#  'Sunrisers Hyderabad',
#  'Sunrisers Hyderabad',
#  'Sunrisers Hyderabad',
#  'Sunrisers Hyderabad',
#  'Sunrisers Hyderabad',
#  'Sunrisers Hyderabad',
#  'Sunrisers Hyderabad',
# ...

# %%
len(Sunrisers_Hyderabad_win)
# Out:
# 58

# %%
Rising_Pune_Supergiant_win = []

for i in dataset[1:]:
    win = i[10]
    if win == 'Rising Pune Supergiant': 
        Rising_Pune_Supergiant_win.append(win)

# %%
Rising_Pune_Supergiant_win
# Out:
# ['Rising Pune Supergiant',
#  'Rising Pune Supergiant',
#  'Rising Pune Supergiant',
#  'Rising Pune Supergiant',
#  'Rising Pune Supergiant',
#  'Rising Pune Supergiant',
#  'Rising Pune Supergiant',
#  'Rising Pune Supergiant',
#  'Rising Pune Supergiant',
#  'Rising Pune Supergiant']

# %%
len(Rising_Pune_Supergiant_win)
# Out:
# 10

# %%
Kings_XI_Punjab_win = []

for i in dataset[1:]:
    win = i[10]
    if win == 'Kings XI Punjab': 
        Kings_XI_Punjab_win.append(win)

# %%
Kings_XI_Punjab_win
# Out:
# ['Kings XI Punjab',
#  'Kings XI Punjab',
#  'Kings XI Punjab',
#  'Kings XI Punjab',
#  'Kings XI Punjab',
#  'Kings XI Punjab',
#  'Kings XI Punjab',
#  'Kings XI Punjab',
#  'Kings XI Punjab',
#  'Kings XI Punjab',
#  'Kings XI Punjab',
#  'Kings XI Punjab',
#  'Kings XI Punjab',
#  'Kings XI Punjab',
#  'Kings XI Punjab',
#  'Kings XI Punjab',
#  'Kings XI Punjab',
#  'Kings XI Punjab',
#  'Kings XI Punjab',
#  'Kings XI Punjab',
#  'Kings XI Punjab',
#  'Kings XI Punjab',
#  'Kings XI Punjab',
#  'Kings XI Punjab',
#  'Kings XI Punjab',
#  'Kings XI Punjab',
#  'Kings XI Punjab',
#  'Kings XI Punjab',
#  'Kings XI Punjab',
#  'Kings XI Punjab',
#  'Kings XI Punjab',
#  'Kings XI Punjab',
#  'Kings XI Punjab',
#  'Kings XI Punjab',
#  'Kings XI Punjab',
#  'Kings XI Punjab',
#  'Kings XI Punjab',
#  'Kings XI Punjab',
#  'Kings XI Punjab',
#  'Kings XI Punjab',
#  'Kings XI Punjab',
#  'Kings XI Punjab',
#  'Kings XI Punjab',
#  'Kings XI Punjab',
#  'Kings XI Punjab',
# ...

# %%
len(Kings_XI_Punjab_win)
# Out:
# 82

# %%
Mumbai_Indians_win = []

for i in dataset[1:]:
    win = i[10]
    if win == 'Mumbai Indians': 
        Mumbai_Indians_win.append(win)

# %%
Mumbai_Indians_win
# Out:
# ['Mumbai Indians',
#  'Mumbai Indians',
#  'Mumbai Indians',
#  'Mumbai Indians',
#  'Mumbai Indians',
#  'Mumbai Indians',
#  'Mumbai Indians',
#  'Mumbai Indians',
#  'Mumbai Indians',
#  'Mumbai Indians',
#  'Mumbai Indians',
#  'Mumbai Indians',
#  'Mumbai Indians',
#  'Mumbai Indians',
#  'Mumbai Indians',
#  'Mumbai Indians',
#  'Mumbai Indians',
#  'Mumbai Indians',
#  'Mumbai Indians',
#  'Mumbai Indians',
#  'Mumbai Indians',
#  'Mumbai Indians',
#  'Mumbai Indians',
#  'Mumbai Indians',
#  'Mumbai Indians',
#  'Mumbai Indians',
#  'Mumbai Indians',
#  'Mumbai Indians',
#  'Mumbai Indians',
#  'Mumbai Indians',
#  'Mumbai Indians',
#  'Mumbai Indians',
#  'Mumbai Indians',
#  'Mumbai Indians',
#  'Mumbai Indians',
#  'Mumbai Indians',
#  'Mumbai Indians',
#  'Mumbai Indians',
#  'Mumbai Indians',
#  'Mumbai Indians',
#  'Mumbai Indians',
#  'Mumbai Indians',
#  'Mumbai Indians',
#  'Mumbai Indians',
#  'Mumbai Indians',
#  'Mumbai Indians',
#  'Mumbai Indians',
# ...

# %%
len(Mumbai_Indians_win)
# Out:
# 109

# %%
Delhi_Daredevils_win = []

for i in dataset[1:]:
    win = i[10]
    if win == 'Delhi Daredevils': 
        Delhi_Daredevils_win.append(win)

# %%
Delhi_Daredevils_win
# Out:
# ['Delhi Daredevils',
#  'Delhi Daredevils',
#  'Delhi Daredevils',
#  'Delhi Daredevils',
#  'Delhi Daredevils',
#  'Delhi Daredevils',
#  'Delhi Daredevils',
#  'Delhi Daredevils',
#  'Delhi Daredevils',
#  'Delhi Daredevils',
#  'Delhi Daredevils',
#  'Delhi Daredevils',
#  'Delhi Daredevils',
#  'Delhi Daredevils',
#  'Delhi Daredevils',
#  'Delhi Daredevils',
#  'Delhi Daredevils',
#  'Delhi Daredevils',
#  'Delhi Daredevils',
#  'Delhi Daredevils',
#  'Delhi Daredevils',
#  'Delhi Daredevils',
#  'Delhi Daredevils',
#  'Delhi Daredevils',
#  'Delhi Daredevils',
#  'Delhi Daredevils',
#  'Delhi Daredevils',
#  'Delhi Daredevils',
#  'Delhi Daredevils',
#  'Delhi Daredevils',
#  'Delhi Daredevils',
#  'Delhi Daredevils',
#  'Delhi Daredevils',
#  'Delhi Daredevils',
#  'Delhi Daredevils',
#  'Delhi Daredevils',
#  'Delhi Daredevils',
#  'Delhi Daredevils',
#  'Delhi Daredevils',
#  'Delhi Daredevils',
#  'Delhi Daredevils',
#  'Delhi Daredevils',
#  'Delhi Daredevils',
# ...

# %%
len(Delhi_Daredevils_win)
# Out:
# 67

# %%
Kolkata_Knight_Riders_win = []

for i in dataset[1:]:
    win = i[10]
    if win == 'Kolkata Knight Riders': 
        Kolkata_Knight_Riders_win.append(win)

# %%
Kolkata_Knight_Riders_win
# Out:
# ['Kolkata Knight Riders',
#  'Kolkata Knight Riders',
#  'Kolkata Knight Riders',
#  'Kolkata Knight Riders',
#  'Kolkata Knight Riders',
#  'Kolkata Knight Riders',
#  'Kolkata Knight Riders',
#  'Kolkata Knight Riders',
#  'Kolkata Knight Riders',
#  'Kolkata Knight Riders',
#  'Kolkata Knight Riders',
#  'Kolkata Knight Riders',
#  'Kolkata Knight Riders',
#  'Kolkata Knight Riders',
#  'Kolkata Knight Riders',
#  'Kolkata Knight Riders',
#  'Kolkata Knight Riders',
#  'Kolkata Knight Riders',
#  'Kolkata Knight Riders',
#  'Kolkata Knight Riders',
#  'Kolkata Knight Riders',
#  'Kolkata Knight Riders',
#  'Kolkata Knight Riders',
#  'Kolkata Knight Riders',
#  'Kolkata Knight Riders',
#  'Kolkata Knight Riders',
#  'Kolkata Knight Riders',
#  'Kolkata Knight Riders',
#  'Kolkata Knight Riders',
#  'Kolkata Knight Riders',
#  'Kolkata Knight Riders',
#  'Kolkata Knight Riders',
#  'Kolkata Knight Riders',
#  'Kolkata Knight Riders',
#  'Kolkata Knight Riders',
# ...

# %%
len(Kolkata_Knight_Riders_win)
# Out:
# 92

# %%
Royal_Challengers_Bangalore_win = []

for i in dataset[1:]:
    win = i[10]
    if win == 'Royal Challengers Bangalore': 
        Royal_Challengers_Bangalore_win.append(win)

# %%
Royal_Challengers_Bangalore_win
# Out:
# ['Royal Challengers Bangalore',
#  'Royal Challengers Bangalore',
#  'Royal Challengers Bangalore',
#  'Royal Challengers Bangalore',
#  'Royal Challengers Bangalore',
#  'Royal Challengers Bangalore',
#  'Royal Challengers Bangalore',
#  'Royal Challengers Bangalore',
#  'Royal Challengers Bangalore',
#  'Royal Challengers Bangalore',
#  'Royal Challengers Bangalore',
#  'Royal Challengers Bangalore',
#  'Royal Challengers Bangalore',
#  'Royal Challengers Bangalore',
#  'Royal Challengers Bangalore',
#  'Royal Challengers Bangalore',
#  'Royal Challengers Bangalore',
#  'Royal Challengers Bangalore',
#  'Royal Challengers Bangalore',
#  'Royal Challengers Bangalore',
#  'Royal Challengers Bangalore',
#  'Royal Challengers Bangalore',
#  'Royal Challengers Bangalore',
#  'Royal Challengers Bangalore',
#  'Royal Challengers Bangalore',
#  'Royal Challengers Bangalore',
#  'Royal Challengers Bangalore',
#  'Royal Challengers Bangalore',
#  'Royal Challengers Bangalore',
# ...

# %%
len(Royal_Challengers_Bangalore_win)
# Out:
# 84

# %%
Gujarat_Lions_win = []

for i in dataset[1:]:
    win = i[10]
    if win == 'Gujarat Lions': 
        Gujarat_Lions_win.append(win)

# %%
Gujarat_Lions_win
# Out:
# ['Gujarat Lions',
#  'Gujarat Lions',
#  'Gujarat Lions',
#  'Gujarat Lions',
#  'Gujarat Lions',
#  'Gujarat Lions',
#  'Gujarat Lions',
#  'Gujarat Lions',
#  'Gujarat Lions',
#  'Gujarat Lions',
#  'Gujarat Lions',
#  'Gujarat Lions',
#  'Gujarat Lions']

# %%
len(Gujarat_Lions_win)
# Out:
# 13

# %%
Deccan_Chargers_win = []

for i in dataset[1:]:
    win = i[10]
    if win == 'Deccan Chargers': 
        Deccan_Chargers_win.append(win)

# %%
Deccan_Chargers_win
# Out:
# ['Deccan Chargers',
#  'Deccan Chargers',
#  'Deccan Chargers',
#  'Deccan Chargers',
#  'Deccan Chargers',
#  'Deccan Chargers',
#  'Deccan Chargers',
#  'Deccan Chargers',
#  'Deccan Chargers',
#  'Deccan Chargers',
#  'Deccan Chargers',
#  'Deccan Chargers',
#  'Deccan Chargers',
#  'Deccan Chargers',
#  'Deccan Chargers',
#  'Deccan Chargers',
#  'Deccan Chargers',
#  'Deccan Chargers',
#  'Deccan Chargers',
#  'Deccan Chargers',
#  'Deccan Chargers',
#  'Deccan Chargers',
#  'Deccan Chargers',
#  'Deccan Chargers',
#  'Deccan Chargers',
#  'Deccan Chargers',
#  'Deccan Chargers',
#  'Deccan Chargers',
#  'Deccan Chargers']

# %%
len(Deccan_Chargers_win)
# Out:
# 29

# %%
Rajasthan_Royals_win = []

for i in dataset[1:]:
    win = i[10]
    if win == 'Rajasthan Royals': 
        Rajasthan_Royals_win.append(win)

# %%
Rajasthan_Royals_win
# Out:
# ['Rajasthan Royals',
#  'Rajasthan Royals',
#  'Rajasthan Royals',
#  'Rajasthan Royals',
#  'Rajasthan Royals',
#  'Rajasthan Royals',
#  'Rajasthan Royals',
#  'Rajasthan Royals',
#  'Rajasthan Royals',
#  'Rajasthan Royals',
#  'Rajasthan Royals',
#  'Rajasthan Royals',
#  'Rajasthan Royals',
#  'Rajasthan Royals',
#  'Rajasthan Royals',
#  'Rajasthan Royals',
#  'Rajasthan Royals',
#  'Rajasthan Royals',
#  'Rajasthan Royals',
#  'Rajasthan Royals',
#  'Rajasthan Royals',
#  'Rajasthan Royals',
#  'Rajasthan Royals',
#  'Rajasthan Royals',
#  'Rajasthan Royals',
#  'Rajasthan Royals',
#  'Rajasthan Royals',
#  'Rajasthan Royals',
#  'Rajasthan Royals',
#  'Rajasthan Royals',
#  'Rajasthan Royals',
#  'Rajasthan Royals',
#  'Rajasthan Royals',
#  'Rajasthan Royals',
#  'Rajasthan Royals',
#  'Rajasthan Royals',
#  'Rajasthan Royals',
#  'Rajasthan Royals',
#  'Rajasthan Royals',
#  'Rajasthan Royals',
#  'Rajasthan Royals',
#  'Rajasthan Royals',
#  'Rajasthan Royals',
# ...

# %%
len(Rajasthan_Royals_win)
# Out:
# 75

# %%
Chennai_Super_Kings_win = []

for i in dataset[1:]:
    win = i[10]
    if win == 'Chennai Super Kings': 
        Chennai_Super_Kings_win.append(win)

# %%
Chennai_Super_Kings_win
# Out:
# ['Chennai Super Kings',
#  'Chennai Super Kings',
#  'Chennai Super Kings',
#  'Chennai Super Kings',
#  'Chennai Super Kings',
#  'Chennai Super Kings',
#  'Chennai Super Kings',
#  'Chennai Super Kings',
#  'Chennai Super Kings',
#  'Chennai Super Kings',
#  'Chennai Super Kings',
#  'Chennai Super Kings',
#  'Chennai Super Kings',
#  'Chennai Super Kings',
#  'Chennai Super Kings',
#  'Chennai Super Kings',
#  'Chennai Super Kings',
#  'Chennai Super Kings',
#  'Chennai Super Kings',
#  'Chennai Super Kings',
#  'Chennai Super Kings',
#  'Chennai Super Kings',
#  'Chennai Super Kings',
#  'Chennai Super Kings',
#  'Chennai Super Kings',
#  'Chennai Super Kings',
#  'Chennai Super Kings',
#  'Chennai Super Kings',
#  'Chennai Super Kings',
#  'Chennai Super Kings',
#  'Chennai Super Kings',
#  'Chennai Super Kings',
#  'Chennai Super Kings',
#  'Chennai Super Kings',
#  'Chennai Super Kings',
#  'Chennai Super Kings',
#  'Chennai Super Kings',
#  'Chennai Super Kings',
# ...

# %%
len(Chennai_Super_Kings_win)
# Out:
# 100

# %%
Gujarat_Lions_win = []

for i in dataset[1:]:
    win = i[10]
    if win == 'Gujarat Lions': 
        Gujarat_Lions_win.append(win)

# %%
Gujarat_Lions_win
# Out:
# ['Gujarat Lions',
#  'Gujarat Lions',
#  'Gujarat Lions',
#  'Gujarat Lions',
#  'Gujarat Lions',
#  'Gujarat Lions',
#  'Gujarat Lions',
#  'Gujarat Lions',
#  'Gujarat Lions',
#  'Gujarat Lions',
#  'Gujarat Lions',
#  'Gujarat Lions',
#  'Gujarat Lions']

# %%
len(Gujarat_Lions_win)
# Out:
# 13

# %% [markdown]
# # find the match id in which RCB won the match by more then 140 runs

# %%
dataset[0].index('win_by_runs')
# Out:
# 11

# %%
for i in dataset[1:]:
    win = i[10]
    win_runs = int(i[11])
    if win == 'Royal Challengers Bangalore' and win_runs > 140:
        print(i[0])
# Out:
# 620

# %%
dataset[0].index('win_by_wickets')
# Out:
# 12

# %%
for i in dataset[1:]:
    win = i[10]
    win_wickets = int(i[11])
    if win == 'Royal Challengers Bangalore' and win_wickets > 9:
        print(i[0], " date of match is : ", i[3])
# Out:
# 5  date of match is :  2017-04-08
# 20  date of match is :  2017-04-18
# 55  date of match is :  2017-05-14
# 107  date of match is :  2008-05-21
# 119  date of match is :  2009-04-18
# 171  date of match is :  2009-05-21
# 192  date of match is :  2010-03-23
# 268  date of match is :  2011-04-29
# 280  date of match is :  2011-05-06
# 306  date of match is :  2011-05-27
# 312  date of match is :  2012-04-07
# 338  date of match is :  2012-04-23
# 362  date of match is :  2012-05-11
# 372  date of match is :  2012-05-17
# 411  date of match is :  2013-04-23
# 426  date of match is :  2013-05-02
# 452  date of match is :  2013-05-18
# 495  date of match is :  2014-05-13
# 557  date of match is :  2015-05-06
# 562  date of match is :  2015-05-10
# 574  date of match is :  2015-05-20
# 580  date of match is :  2016-04-12
# 592  date of match is :  2016-04-22
# 620  date of match is :  2016-05-14
# 626  date of match is :  2016-05-18
# 7924  date of match is :  01/05/18
# ...

# %% [markdown]
# # RCB won the match with choosing bat after the toss

# %%
dataset[0].index('toss_decision')
# Out:
# 7

# %%
dataset[0].index('winner')
# Out:
# 10

# %%
dataset[0].index('toss_winner')
# Out:
# 6

# %%
win_with_bat = 0
for i in dataset[1:]:
    dec = i[7]
    win = i[10]
    toss = i[6]
    if toss == 'Royal Challengers Bangalore' and win == 'Royal Challengers Bangalore' and dec == 'bat':
        win_with_bat += 1
win_with_bat
# Out:
# 9

# %% [markdown]
# # RCB won the match with choosing bat after the toss¶

# %%
win_with_field = 0
for i in dataset[1:]:
    dec = i[7]
    win = i[10]
    toss = i[6]
    if toss == 'Royal Challengers Bangalore' and win == 'Royal Challengers Bangalore' and dec == 'field':
        win_with_field += 1
win_with_field
# Out:
# 32

# %% [markdown]
# # RCB Won the match while playing in Pune

# %%
dataset[0].index('city')
# Out:
# 2

# %%
for i in dataset[1:]:
    city = i[2]
    win = i[10]
    if win == 'Royal Challengers Bangalore' and city == 'Pune':
        print("Season ==> ", i[1]," Date ==> ",i[3]," City ==> ",city)
# Out:
# Season ==>  2012  Date ==>  11/05/2012  City ==>  Pune
# Season ==>  2013  Date ==>  02/05/2013  City ==>  Pune
# Season ==>  2015  Date ==>  20/05/2015  City ==>  Pune
# Season ==>  2016  Date ==>  22/04/2016  City ==>  Pune

# %% [markdown]
# # RCB won the match after winning the match in Pune

# %%
for i in dataset[1:]:
    city = i[2]
    win = i[10]
    toss = i[6]
    if win == 'Royal Challengers Bangalore' and city == 'Pune' and toss == 'Royal Challengers Bangalore':
        print("Season ==> ", i[1]," Date ==> ",i[3]," City ==> ",city)
# Out:
# Season ==>  2013  Date ==>  02/05/2013  City ==>  Pune
# Season ==>  2015  Date ==>  20/05/2015  City ==>  Pune

# %%
dataset[0].index('player_of_match')
# Out:
# 13

# %%
# Zaheer Khan man of the match trophies
for i in dataset[1:]:
    MOTM = i[13]
    if MOTM == 'Z Khan':
        print("Season ==> ",i[1], "City ==> ",i[2], " Date ==> ",i[3])
# Out:
# Season ==>  2015 City ==>  Raipur  Date ==>  12/05/2015

# %%
# virat Kohli won man of the match trophies
for i in dataset[1:]:
    MOTM = i[13]
    if MOTM == 'V Kohli':
        print("Season ==> ",i[1], "City ==> ",i[2], " Date ==> ",i[3])
# Out:
# Season ==>  2011 City ==>  Delhi  Date ==>  26/04/2011
# Season ==>  2011 City ==>  Bangalore  Date ==>  29/04/2011
# Season ==>  2013 City ==>  Bangalore  Date ==>  16/04/2013
# Season ==>  2013 City ==>  Bangalore  Date ==>  09/04/2013
# Season ==>  2013 City ==>  Bangalore  Date ==>  18/05/2013
# Season ==>  2015 City ==>  Hyderabad  Date ==>  15/05/2015
# Season ==>  2016 City ==>  Rajkot  Date ==>  24/04/2016
# Season ==>  2016 City ==>  Bangalore  Date ==>  07/05/2016
# Season ==>  2016 City ==>  Kolkata  Date ==>  16/05/2016
# Season ==>  2016 City ==>  Bangalore  Date ==>  18/05/2016
# Season ==>  2016 City ==>  Raipur  Date ==>  22/05/2016
# Season ==>  2019 City ==>  Kolkata  Date ==>  19/04/2019

# %%
# ABD won man of the match trophies
for i in dataset[1:]:
    MOTM = i[13]
    if MOTM == 'AB de Villiers':
        print("Season ==> ",i[1], "City ==> ",i[2], " Date ==> ",i[3])
# Out:
# Season ==>  2009 City ==>  Durban  Date ==>  23/04/2009
# Season ==>  2009 City ==>  Bloemfontein  Date ==>  17/05/2009
# Season ==>  2011 City ==>  Kochi  Date ==>  09/04/2011
# Season ==>  2012 City ==>  Bangalore  Date ==>  07/04/2012
# Season ==>  2012 City ==>  Jaipur  Date ==>  23/04/2012
# Season ==>  2012 City ==>  Bangalore  Date ==>  06/05/2012
# Season ==>  2013 City ==>  Pune  Date ==>  02/05/2013
# Season ==>  2014 City ==>  Bangalore  Date ==>  04/05/2014
# Season ==>  2014 City ==>  Ranchi  Date ==>  18/05/2014
# Season ==>  2015 City ==>  Mumbai  Date ==>  10/05/2015
# Season ==>  2015 City ==>  Pune  Date ==>  20/05/2015
# Season ==>  2016 City ==>  Bangalore  Date ==>  12/04/2016
# Season ==>  2016 City ==>  Pune  Date ==>  22/04/2016
# Season ==>  2016 City ==>  Bangalore  Date ==>  14/05/2016
# Season ==>  2016 City ==>  Bangalore  Date ==>  24/05/2016
# Season ==>  2018 City ==>  Bengaluru  Date ==>  21/04/2018
# ...

# %%
dataset[0].index('winner')
# Out:
# 10

# %% [markdown]
# # Number of Matches in Wankede Stadium and there winners

# %%
dataset[0].index('venue')
# Out:
# 14

# %%
wankede_stadium_matches = 0
for i in dataset[1:]:
    ven = i[14]
    if ven == 'Wankhede Stadium':
        wankede_stadium_matches += 1
        print("Season ==> ",i[1], "     Date ==>  ",i[3], '   Winning team ==> ',i[14])
wankede_stadium_matches
# Out:
# Season ==>  2017      Date ==>   09/04/2017    Winning team ==>  Wankhede Stadium
# Season ==>  2017      Date ==>   12/04/2017    Winning team ==>  Wankhede Stadium
# Season ==>  2017      Date ==>   16/04/2017    Winning team ==>  Wankhede Stadium
# Season ==>  2017      Date ==>   22/04/2017    Winning team ==>  Wankhede Stadium
# Season ==>  2017      Date ==>   24/04/2017    Winning team ==>  Wankhede Stadium
# Season ==>  2017      Date ==>   01/05/2017    Winning team ==>  Wankhede Stadium
# Season ==>  2017      Date ==>   11/05/2017    Winning team ==>  Wankhede Stadium
# Season ==>  2017      Date ==>   16/05/2017    Winning team ==>  Wankhede Stadium
# Season ==>  2008      Date ==>   20/04/2008    Winning team ==>  Wankhede Stadium
# Season ==>  2008      Date ==>   14/05/2008    Winning team ==>  Wankhede Stadium
# Season ==>  2008      Date ==>   16/05/2008    Winning team ==>  Wankhede Stadium
# ...

# %%
dataset[0].index('win_by_runs')
# Out:
# 11

# %%
dataset[0].index('winner')
# Out:
# 10

# %%
for i in dataset[1:]:
    win_runs = int(i[11])
    if win_runs == 146:
        print(i[10], ' Against ===> ', i[5], ' on ', i[3])
# Out:
# Mumbai Indians  Against ===>  Delhi Daredevils  on  06/05/2017
