# %% [markdown]
# © 2022 Techmazone or its affiliated partners. All rights reserved.

# %% [markdown]
# # Print Function :

# %% [markdown]
# ### _The tallest man ever recorded was Robert Wadlow (USA). He was 8.11 tall. He died at the age of 22._

# %% [markdown]
# Q1) What is the name of the man?
#
# >(Print the name of the man in string)
#
# >(Print the type)

# %% [markdown]
# Q2) What is the age of the man ?
# >(Print the age in integer)
#
# >(Print the type)

# %% [markdown]
# Q3) What is the height of the man ?
#
# >(Print the height in float)
#
# >(Print the type)

# %% [markdown]
# # Arithmetic Operation

# %% [markdown]
# ### _You sold 320 chocolate cookies and 270 vanilla cookies._

# %% [markdown]
# Q) How many total cookies did you sell ? (Print the addition)

# %% [markdown]
# ### _I had 5000rs with me. Out of it 3585rs was spent._

# %% [markdown]
# Q) Now how much money do I have? (Print the subtraction)

# %% [markdown]
# ### _There are 226 pencils in a packet._

# %% [markdown]
# Q) How many pencils are there in 212 such packets? (Print the multiplication)

# %% [markdown]
# ### _5,876rs are distributed equally among 26 men._

# %% [markdown]
# Q) How much money will each person get?

# %% [markdown]
# ### _What is 32 raise to the power 3 ?_

# %% [markdown]
# Q) Print the exponent

# %% [markdown]
# ### _What is the remainder if 582 is divided by 5 ?_

# %% [markdown]
# Q) Print the remainder using Modulo (%) operation

# %% [markdown]
# # PEMDAS

# %% [markdown]
# ### _10**2+(15+29)*9-1_

# %% [markdown]
# Q) Dry Run the above equation using comments like we did in class and match the answer.

# %% [markdown]
# # Variables

# %% [markdown]
# ![thequint_2021-04_bb0c741a-a843-4e57-a457-3aa70bcfd436_3%20%281%29.png](attachment:thequint_2021-04_bb0c741a-a843-4e57-a457-3aa70bcfd436_3%20%281%29.png)

# %% [markdown]
# #### Storage

# %% [markdown]
# Q) Store the name of cricketers in two seprate name variables (e.g cricketer_1 , cricketer_2)

# %% [markdown]
# Q) Store the average of babar in a average variable.

# %% [markdown]
# Q) Store the centuries of babar in a hundred variable

# %% [markdown]
# #### Printing multiple variables in a single line

# %% [markdown]
# Q) Print all the details of babar in a single print statement. (Use escape sequences too)
