# %%
import requests
from bs4 import BeautifulSoup

# %%
base_site = 'https://www.apple.com/'
response = requests.get(base_site)

# %%
response
# Out:
# <Response [200]>

# %%
html = response.content

# %%
html
# Out:
# b'\n\n\n\t\n\n\n\t\n\n\t\n\n\n\t\n\n\n\t\n\n\t\n\t\t\n\t\n\n\t\n\n\t\t\n\t\t\n\n\t\n\n\n\t\n\n\n\t\t\t\t\n\n\t\t\t\t\t\n\n\t\t\t\t\n\n\n\t\t\t\t\n\n\t\t\t\t\t\n\n\t\t\t\t\n\n\n\t\t\t\t\n\n\t\t\t\t\t\n\t\t\t\t\t\t\n\n\n\n<!DOCTYPE html>\n<html xmlns="http://www.w3.org/1999/xhtml" xml:lang="en-US" lang="en-US" prefix="og: http://ogp.me/ns#" class="no-js" data-layout-name="superbowl">\n<head>\n\t\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n<meta charset="utf-8" />\n<link rel="canonical" href="https://www.apple.com/" />\n\n\n\t\n\t<link rel="alternate" href="https://www.apple.com/" hreflang="en-US" /><link rel="alternate" href="https://www.apple.com/ae-ar/" hreflang="ar-AE" /><link rel="alternate" href="https://www.apple.com/ae/" hreflang="en-AE" /><link rel="alternate" href="https://www.apple.com/am/" hreflang="en-AM" /><link rel="alternate" href="https://www.apple.com/at/" hreflang="de-AT" /><link rel="alternate" href="https://www.apple.com/au/" hreflang="en-AU" />
# ...

# %%
html[:5000]
# Out:
# b'\n\n\n\t\n\n\n\t\n\n\t\n\n\n\t\n\n\n\t\n\n\t\n\t\t\n\t\n\n\t\n\n\t\t\n\t\t\n\n\t\n\n\n\t\n\n\n\t\t\t\t\n\n\t\t\t\t\t\n\n\t\t\t\t\n\n\n\t\t\t\t\n\n\t\t\t\t\t\n\n\t\t\t\t\n\n\n\t\t\t\t\n\n\t\t\t\t\t\n\t\t\t\t\t\t\n\n\n\n<!DOCTYPE html>\n<html xmlns="http://www.w3.org/1999/xhtml" xml:lang="en-US" lang="en-US" prefix="og: http://ogp.me/ns#" class="no-js" data-layout-name="superbowl">\n<head>\n\t\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n<meta charset="utf-8" />\n<link rel="canonical" href="https://www.apple.com/" />\n\n\n\t\n\t<link rel="alternate" href="https://www.apple.com/" hreflang="en-US" /><link rel="alternate" href="https://www.apple.com/ae-ar/" hreflang="ar-AE" /><link rel="alternate" href="https://www.apple.com/ae/" hreflang="en-AE" /><link rel="alternate" href="https://www.apple.com/am/" hreflang="en-AM" /><link rel="alternate" href="https://www.apple.com/at/" hreflang="de-AT" /><link rel="alternate" href="https://www.apple.com/au/" hreflang="en-AU" />
# ...

# %%
# this is not in goood form so we will use parser to make it proper

# %%
soup = BeautifulSoup(html, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html class="no-js" data-layout-name="superbowl" lang="en-US" prefix="og: http://ogp.me/ns#" xml:lang="en-US" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <link href="https://www.apple.com/" rel="canonical"/>
# ...

# %% [markdown]
# # Scraping title

# %% [markdown]
# # using tags to scrap

# %%
title = soup.find('title')

# %%
title
# Out:
# <title>Apple</title>

# %%
title.text
# Out:
# 'Apple'

# %% [markdown]
# # Scraping Hyperlinks

# %%
link = soup.find('a')

# %%
link
# Out:
# <a aria-label="Apple" class="globalnav-link globalnav-link-apple" data-analytics-title="apple home" data-globalnav-item-name="apple" href="/"><span class="globalnav-image-regular globalnav-link-image"><svg height="44" viewbox="0 0 14 44" width="14" xmlns="http://www.w3.org/2000/svg"><path d="m13.0729 17.6825a3.61 3.61 0 0 0 -1.7248 3.0365 3.5132 3.5132 0 0 0 2.1379 3.2223 8.394 8.394 0 0 1 -1.0948 2.2618c-.6816.9812-1.3943 1.9623-2.4787 1.9623s-1.3633-.63-2.613-.63c-1.2187 0-1.6525.6507-2.644.6507s-1.6834-.9089-2.4787-2.0243a9.7842 9.7842 0 0 1 -1.6628-5.2776c0-3.0984 2.014-4.7405 3.9969-4.7405 1.0535 0 1.9314.6919 2.5924.6919.63 0 1.6112-.7333 2.8092-.7333a3.7579 3.7579 0 0 1 3.1604 1.5802zm-3.7284-2.8918a3.5615 3.5615 0 0 0 .8469-2.22 1.5353 1.5353 0 0 0 -.031-.32 3.5686 3.5686 0 0 0 -2.3445 1.2084 3.4629 3.4629 0 0 0 -.8779 2.1585 1.419 1.419 0 0 0 .031.2892 1.19 1.19 0 0 0 .2169.0207 3.0935 3.0935 0 0 0 2.1586-1.1368z"></path></svg></span><span class="globalnav-image-compact glob
# ...

# %%
link.text
# Out:
# 'Apple'

# %%
links = soup.find_all('a')
links
# Out:
# [<a aria-label="Apple" class="globalnav-link globalnav-link-apple" data-analytics-title="apple home" data-globalnav-item-name="apple" href="/"><span class="globalnav-image-regular globalnav-link-image"><svg height="44" viewbox="0 0 14 44" width="14" xmlns="http://www.w3.org/2000/svg"><path d="m13.0729 17.6825a3.61 3.61 0 0 0 -1.7248 3.0365 3.5132 3.5132 0 0 0 2.1379 3.2223 8.394 8.394 0 0 1 -1.0948 2.2618c-.6816.9812-1.3943 1.9623-2.4787 1.9623s-1.3633-.63-2.613-.63c-1.2187 0-1.6525.6507-2.644.6507s-1.6834-.9089-2.4787-2.0243a9.7842 9.7842 0 0 1 -1.6628-5.2776c0-3.0984 2.014-4.7405 3.9969-4.7405 1.0535 0 1.9314.6919 2.5924.6919.63 0 1.6112-.7333 2.8092-.7333a3.7579 3.7579 0 0 1 3.1604 1.5802zm-3.7284-2.8918a3.5615 3.5615 0 0 0 .8469-2.22 1.5353 1.5353 0 0 0 -.031-.32 3.5686 3.5686 0 0 0 -2.3445 1.2084 3.4629 3.4629 0 0 0 -.8779 2.1585 1.419 1.419 0 0 0 .031.2892 1.19 1.19 0 0 0 .2169.0207 3.0935 3.0935 0 0 0 2.1586-1.1368z"></path></svg></span><span class="globalnav-image-compact glo
# ...

# %%
#links.text             #This will give an error because the links are in list form so for that we need to put it in for loop

# %%
for link in links:
    print(link.text)
# Out:
# Apple
# Store
# Mac
# iPad
# iPhone
# Watch
# AirPods
# TV & Home
# Entertainment
# Accessories
# Support
#
#
#
#
#
#
# Listen on Apple Music
#
# Learn more
# Buy
#
# Learn more
# Buy
#
# Learn more
# Buy
#
# Learn more
# Buy
#
# Learn more
# Buy
#
# Shop now
#
# Learn more
#
# Learn more
# Apply now
# support.apple.com/kb/HT209218
# Store
# Mac
# iPad
# iPhone
# Watch
# AirPods
# TV & Home
# AirTag
# Accessories
# Gift Cards
# Wallet
# Apple Card
# Apple Pay
# Apple Cash
# Manage Your Apple ID
# Apple Store Account
# iCloud.com
# Apple One
# Apple TV+
# Apple Music
# Apple Arcade
# Apple Fitness+
# Apple News+
# Apple Podcasts
# Apple Books
# App Store
# Find a Store
# Genius Bar
# Today at Apple
# Apple Camp
# Apple Store App
# Refurbished and Clearance
# Financing
# Apple Trade In
# Order Status
# Shopping Help
# Apple and Business
# Shop for Business
# Apple and Education
# Shop for K-12
# Shop for College
# Apple in Healthcare
# Health on Apple Watch
# Health Records on iPhone
# ...

# %%
s = soup.find(class_ = 't-body')

# %%
s
